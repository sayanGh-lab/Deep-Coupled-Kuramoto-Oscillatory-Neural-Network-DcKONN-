# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, LSTM, TimeDistributed, Dropout
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.layers import Dense, Flatten, LSTM,Dropout,Conv2D,TimeDistributed
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
#data = sio.loadmat('D:/lab_work_25/AUG/ecg_classification/trainingset.mat')
# Out:
# d:\pYthon_Directory\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# d:\pYthon_Directory\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
#cls_0 = np.load("D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/Alpha/class_0.npy")
#cls_1 = np.load("D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/Alpha/class_1.npy")
#cls_2 = np.load("D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/Alpha/class_2.npy")
#cls_3 = np.load("D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/Alpha/class_3.npy")
#cls_4 = np.load("D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/Alpha/class_4.npy")
#cls_5 = np.load("D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/Alpha/class_5.npy")
cls_6 = np.load("D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/Alpha/class_6.npy")
#cls_7 = np.load("D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/Alpha/class_7.npy")
cls_8 = np.load("D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/Alpha/class_8.npy")

'''print(cls_0.shape)
print(cls_1.shape)
print(cls_2.shape)
print(cls_3.shape)
print(cls_4.shape)
print(cls_5.shape)'''
print(cls_6.shape)
#print(cls_7.shape)
print(cls_8.shape)
# Out:
# (479, 128, 14)
# (443, 128, 14)

# %%
plt.plot(cls_6[15,:,0])

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# all_data shape: (456, 128, 14)

# Reshape to (456*128, 14) so that each channel is a feature
reshaped = cls_6.reshape(-1, cls_6.shape[2])   # (456*128, 14)

# Fit scaler on all data
scaler = StandardScaler()
reshaped_z = scaler.fit_transform(reshaped)

# Reshape back to (456, 128, 14)
cls_0_z = reshaped_z.reshape(cls_6.shape)

print("After Z-score:", cls_0_z.shape)

# Take first 450 trials
cls_0_normalized = cls_0_z[:440]
print("First 450 trials shape:", cls_0_normalized.shape)
# Out:
# After Z-score: (479, 128, 14)
# First 450 trials shape: (440, 128, 14)

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# cls_1 shape: (456, 128, 14)

# Reshape to (456*128, 14) so that each channel is a feature
reshaped_1 = cls_8.reshape(-1, cls_8.shape[2])   # (456*128, 14)

# Fit scaler on all data (separately for cls_1)
scaler_1 = StandardScaler()
reshaped_1_z = scaler_1.fit_transform(reshaped_1)

# Reshape back to (456, 128, 14)
cls_1_z = reshaped_1_z.reshape(cls_8.shape)

print("After Z-score (cls_1):", cls_1_z.shape)

# Take first 450 trials
cls_1_normalized = cls_1_z[:440]
print("First 450 trials shape (cls_1):", cls_1_normalized.shape)
# Out:
# After Z-score (cls_1): (443, 128, 14)
# First 450 trials shape (cls_1): (440, 128, 14)

# %%
cls_0_normalized.shape
# Out:
# (440, 128, 14)

# %%
eeg_data=np.concatenate((cls_0_normalized,cls_1_normalized),axis=0)
eeg_data.shape
# Out:
# (880, 128, 14)

# %%
import numpy as np

# Define base signals
time_points = 128
zero_signal = np.zeros(time_points)
ramp_signal = np.linspace(0, 4, time_points)   # ramp from 0 → 4

# First 450 samples: [zero, ramp]
block1 = np.stack([zero_signal, ramp_signal], axis=-1)  # shape (128,2)
block1 = np.tile(block1, (440,1,1))                     # shape (450,128,2)

# Next 450 samples: [ramp, zero]
block2 = np.stack([ramp_signal, zero_signal], axis=-1)  # shape (128,2)
block2 = np.tile(block2, (440,1,1))                     # shape (450,128,2)

# Concatenate to get final signal
final_signal = np.concatenate([block1, block2], axis=0)  # shape (900,128,2)

print("Final shape:", final_signal.shape)
# Out:
# Final shape: (880, 128, 2)

# %%
plt.plot(final_signal[50,:,:])
# Out:
# [<matplotlib.lines.Line2D at 0x1e9e89b8460>,
#  <matplotlib.lines.Line2D at 0x1e9e89b84c0>]

# %%
from sklearn.model_selection import train_test_split
# Train-test split with shuffling
X_train, X_test, y_train, y_test = train_test_split(
    eeg_data, final_signal, test_size=0.2, shuffle=True, random_state=42
)
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (704, 128, 14)
# y_train shape: (704, 128, 2)
# X_test shape: (176, 128, 14)
# y_test shape: (176, 128, 2)

# %%
X_train=X_train[:700]
y_train=y_train[:700]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (700, 128, 14)
# (700, 128, 2)
# (176, 128, 14)
# (176, 128, 2)

# %%
X_cls0_inter=eeg_data[:20]
X_cls1_inter=eeg_data[600:620]
print(X_cls0_inter.shape)
print(X_cls1_inter.shape)
# Out:
# (20, 128, 14)
# (20, 128, 14)

# %%
plt.plot(cls_0_normalized[135,:,0])
plt.plot(cls_1_normalized[135,:,0])

# %%
'''x_train = np.squeeze(x_train, axis=-1)
print(x_train.shape)'''
# Out:
# 'x_train = np.squeeze(x_train, axis=-1)\nprint(x_train.shape)'

# %%
'''import numpy as np

# Example batch size and ytrain shape for demonstration
batch_size = 45083
ytrain = ytrain   # Generate a random ytrain for demonstration

# Initialize an empty list to store the results for all samples
all_samples = []

# Iterate over each sample in the batch
for sample in ytrain:
    ans = []
    for i in sample:
        if i == 1:
            s = np.linspace(0, 0.25, 32)
            ans.append(s)
        else:
            s = np.zeros(32)
            ans.append(s)
    
    # Convert the list to a NumPy array and then transpose it to get (32, 10)
    ans_array = np.array(ans).T
    all_samples.append(ans_array)

# Convert the list of all_samples to a NumPy array
all_samples_array = np.array(all_samples)  # This should have shape (45083, 32, 10)

# Print the shape to verify
print("Shape of the final array:", all_samples_array.shape)

# Optionally, print the first sample to verify its content
print("First sample:\n", all_samples_array[0])'''
# Out:
# 'import numpy as np\n\n# Example batch size and ytrain shape for demonstration\nbatch_size = 45083\nytrain = ytrain   # Generate a random ytrain for demonstration\n\n# Initialize an empty list to store the results for all samples\nall_samples = []\n\n# Iterate over each sample in the batch\nfor sample in ytrain:\n    ans = []\n    for i in sample:\n        if i == 1:\n            s = np.linspace(0, 0.25, 32)\n            ans.append(s)\n        else:\n            s = np.zeros(32)\n            ans.append(s)\n    \n    # Convert the list to a NumPy array and then transpose it to get (32, 10)\n    ans_array = np.array(ans).T\n    all_samples.append(ans_array)\n\n# Convert the list of all_samples to a NumPy array\nall_samples_array = np.array(all_samples)  # This should have shape (45083, 32, 10)\n\n# Print the shape to verify\nprint("Shape of the final array:", all_samples_array.shape)\n\n# Optionally, print the first sample to verify its content\nprint("First sample:\n", all_samples_array[0])'

# %%
import tensorflow as tf
import numpy as np

# =====================================
# Utilities: adjacency (local coupling)
# =====================================

def build_ring_adjacency(units: int, neighbors: int = 2, periodic: bool = True) -> tf.Tensor:
    
    adj = np.zeros((units, units), dtype=np.float32)
    for i in range(units):
        for d in range(1, neighbors + 1):
            if periodic:
                j1 = (i - d) % units
                j2 = (i + d) % units
                adj[i, j1] = 1.0
                adj[i, j2] = 1.0
            else:
                j1 = i - d
                j2 = i + d
                if 0 <= j1 < units:
                    adj[i, j1] = 1.0
                if 0 <= j2 < units:
                    adj[i, j2] = 1.0
    np.fill_diagonal(adj, 0.0)
    return tf.convert_to_tensor(adj, dtype=tf.float32)


def zero_diag(x: tf.Tensor) -> tf.Tensor:
    n = tf.shape(x)[0]
    return x * (1.0 - tf.eye(n, dtype=x.dtype))


# =====================================
# Kuramoto loop: local coupling + Hebbian
# =====================================

@tf.function
def kuramoto_loop_local_hebb(
    X_r: tf.Tensor,
    X_i: tf.Tensor,
    omegas: tf.Tensor,
    num_steps: int,
    K: tf.Variable,
    adjacency: tf.Tensor,
    *,
    dt: float = 1.0/128.0,
    input_scaler: float = 2.0,
    eta: float = 0.01,          # Hebbian learning rate
    decay: float = 0.001,       # weight decay to prevent blow-up
    k_clip: float = 1.0,        # clip |K_ij| <= k_clip
    wrap_phase: bool = True,
    normalize_rows: bool = False,
    symmetric_K: bool = True,
) -> tuple[tf.Tensor, tf.Variable]:
    
    batch = tf.shape(X_r)[0]
    units = tf.shape(X_r)[-1]

    phi_arr = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
    phis = tf.zeros((batch, units), dtype=tf.float32)  # initial phase = 0

    # Precompute for normalization if requested
    if normalize_rows:
        deg = tf.reduce_sum(adjacency, axis=1, keepdims=True)  # (units, 1)
        deg = tf.maximum(deg, 1.0)

    two_pi = tf.constant(2.0 * np.pi, dtype=tf.float32)
    pi = tf.constant(np.pi, dtype=tf.float32)

    for t in tf.range(num_steps):
        # External input projection on phase (driven oscillator)
        input_r = input_scaler * X_r[:, t, :] * tf.math.cos(phis)
        input_i = input_scaler * X_i[:, t, :] * tf.math.sin(phis)

        # Coupling term: sum_j K_ij * sin(phi_j - phi_i)
        # delta[i,j] = phi_i - phi_j (batch, i, j)
        delta = tf.expand_dims(phis, 1) - tf.expand_dims(phis, 2)
        # sin(phi_j - phi_i) = -sin(phi_i - phi_j) = -sin(delta)
        sin_term = -tf.math.sin(delta)  # (batch, i, j)
        # multiply by masked K (i,j) and sum over j
        K_eff = adjacency * K  # (i, j)
        if normalize_rows:
            K_eff = K_eff / deg  # row-normalize by degree
        coup = tf.einsum('ij,bij->bi', K_eff, sin_term)  # (batch, i)

        # Euler step for phase update
        dphi = (omegas + input_r - input_i + coup) * dt
        phis = phis + dphi

        # Optionally wrap phases to [-pi, pi)
        if wrap_phase:
            phis = ((phis + pi) % two_pi) - pi

        # Hebbian plasticity update (average over batch at current t)
        # hebb[i,j] ~ cos(phi_i - phi_j)
        hebb = tf.reduce_mean(tf.math.cos(delta), axis=0)  # (i, j)
        dK = eta * (adjacency * hebb) - decay * K
        K.assign_add(dK)

        # Stabilize: enforce symmetry if desired, zero diagonal, clip
        if symmetric_K:
            K.assign(0.5 * (K + tf.transpose(K)))
        K.assign(zero_diag(K))
        if k_clip is not None:
            K.assign(tf.clip_by_value(K, -k_clip, k_clip))

        phi_arr = phi_arr.write(phi_arr.size(), phis)

    phis = tf.transpose(phi_arr.stack(), [1, 0, 2])  # (batch, time, units)
    return phis, K


# =====================================
# Kuramoto Layer with local Hebbian K
# =====================================

class KuramotoLocal(tf.keras.layers.Layer):
    def __init__(self,
                 units: int,
                 num_steps: int,
                 *,
                 min_omega: float = 8.1,
                 max_omega: float = 12.1,
                 train_omegas: bool = True,
                 neighbors: int = 2,
                 periodic: bool = True,
                 eta: float = 0.001,
                 decay: float = 0.001,
                 k_clip: float = 1.0,
                 normalize_rows: bool = False,
                 symmetric_K: bool = True,
                 dt: float = 1.0/128.0,
                 input_scaler: float = 2.0,
                 wrap_phase: bool = True,
                 name: str = None,
                 **kwargs):
        super().__init__(name=name, **kwargs)
        self.units = units
        self.num_steps = num_steps
        self.min_omega = min_omega
        self.max_omega = max_omega
        self.train_omegas = train_omegas
        self.neighbors = neighbors
        self.periodic = periodic
        self.eta = eta
        self.decay = decay
        self.k_clip = k_clip
        self.normalize_rows = normalize_rows
        self.symmetric_K = symmetric_K
        self.dt = dt
        self.input_scaler = input_scaler
        self.wrap_phase = wrap_phase

        # Intrinsic frequencies parameter (1, units)
        omega_init = tf.random.uniform((1, units), -1, 1)
        self.omegas = tf.Variable(omega_init, trainable=train_omegas, name="omegas")

        # Coupling matrix (units, units), updated by Hebbian rule inside call
        k_init = tf.random.uniform((units, units), -0.05, 0.05)
        self.K = tf.Variable(k_init, trainable=False, name="K")

        # Adjacency (mask): only local neighbors
        self.adjacency = build_ring_adjacency(units, neighbors, periodic)

    def call(self, X_r: tf.Tensor, X_i: tf.Tensor):
        # Map omegas to [min_omega, max_omega]
        omega_range = self.max_omega - self.min_omega
        omega_inp = tf.sigmoid(0.5 * self.omegas) * omega_range + self.min_omega

        phis, _ = kuramoto_loop_local_hebb(
            X_r, X_i, omega_inp, self.num_steps,
            self.K, self.adjacency,
            dt=self.dt,
            input_scaler=self.input_scaler,
            eta=self.eta,
            decay=self.decay,
            k_clip=self.k_clip,
            wrap_phase=self.wrap_phase,
            normalize_rows=self.normalize_rows,
            symmetric_K=self.symmetric_K,
        )

        z_real = tf.math.cos(phis)
        z_imag = tf.math.sin(phis)
        return z_real, z_imag


# =====================================
# Example end-to-end model using the layer
# =====================================

class Model(tf.keras.Model):
    def __init__(self, units1, units2, units3, units4,  **kwargs):
        super().__init__(**kwargs)
        # Feature projection for real/imag pathways
        self.d1_r = tf.keras.layers.Dense(units1, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4))
        self.d1_i = tf.keras.layers.Dense(units1, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4))

        # Project to oscillator count (units2) for each pathway
        self.proj_r = tf.keras.layers.Dense(units2, activation=None)
        self.proj_i = tf.keras.layers.Dense(units2, activation=None)

        # Local Kuramoto oscillator block
        self.osc1 = KuramotoLocal(
            units=units2,
            num_steps=128,
            min_omega=8.1,
            max_omega=12.1,
            train_omegas=True,
            neighbors=2,          # 2 on each side => 4 neighbors total
            periodic=True,
            eta=5e-4, 
            decay=0.001,
            k_clip=0.5,
            normalize_rows=False,
            symmetric_K=True,
            dt=1.0/128.0,
            input_scaler=2.0,
            wrap_phase=True,
        )

        # Post-oscillator dense on each channel (real/imag separately)
        self.d_r = tf.keras.layers.Dense(units3, activation='tanh')
        self.dropout_r = tf.keras.layers.Dropout(0.3)
        self.d_i = tf.keras.layers.Dense(units3, activation='tanh')
        self.dropout_i = tf.keras.layers.Dropout(0.3)

        # Shared dense and output
        self.dense = tf.keras.layers.Dense(units4, activation='linear')
        #self.out_dense = tf.keras.layers.Dense(units5, activation='linear')

    def call(self, X: tf.Tensor,training=False):
        # X: (batch, time, features)
        td = tf.keras.layers.TimeDistributed

        # Pathway feature extraction
        out1_r = td(self.d1_r)(X)
        out1_i = td(self.d1_i)(X)

        # Project to oscillator dimension (units2)
        X_r = td(self.proj_r)(out1_r)
        X_i = td(self.proj_i)(out1_i)

        # Kuramoto oscillator (returns cos(phi), sin(phi))
        z1_r, z1_i = self.osc1(X_r, X_i)

        # Post-oscillator processing (per time step)
        out2_r = td(self.d_r)(z1_r)
        out2_r = td(self.dropout_r)(out2_r, training=training)
        out2_i = td(self.d_i)(z1_i)
        out2_i = td(self.dropout_i)(out2_i, training=training)

        # Concatenate real + imag pathways
        concat_inp = tf.concat([out2_r, out2_i], axis=-1)

        # Shared dense + output
        denseout = td(self.dense)(concat_inp)
        #out_final = td(self.out_dense)(denseout)
        return denseout

# %%
model = Model(40,40,20,2)

# %%
model.build(input_shape=(720, 128, 14))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               multiple                  600
#
#  dense_1 (Dense)             multiple                  600
#
#  dense_2 (Dense)             multiple                  1640
#
#  dense_3 (Dense)             multiple                  1640
#
#  kuramoto_local (KuramotoLoc  multiple                 1640
#  al)
#
#  dense_4 (Dense)             multiple                  820
#
#  dropout (Dropout)           multiple                  0
#
#  dense_5 (Dense)             multiple                  820
#
#  dropout_1 (Dropout)         multiple                  0
#
#  dense_6 (Dense)             multiple                  82
#
# =================================================================
# Total params: 7,842
# Trainable params: 6,242
# Non-trainable params: 1,600
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(0.001)


model.compile(optimizer, 'mse', metrics=['accuracy'])

# %%
'''p=X_train_train[:45000,:,:].shape
print(p)'''
# Out:
# 'p=X_train_train[:45000,:,:].shape\nprint(p)'

# %%
'''all_samples_array.shape
x=all_samples_array[:45000,:,:]
print(x.shape)'''
# Out:
# 'all_samples_array.shape\nx=all_samples_array[:45000,:,:]\nprint(x.shape)'

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
import os

# directory where weights will be saved
save_dir = r"D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights"
os.makedirs(save_dir, exist_ok=True)   # create folder if missing

weights_path = os.path.join(save_dir, "audio_visual_yes_no_part2.h5")
print("Weights will be saved at:", weights_path)

from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_weights = ModelCheckpoint(
    filepath=weights_path,
    monitor="val_loss",
    save_best_only=True,
    save_weights_only=True,
    mode="min",
    verbose=1
)

history_linear_4 = model.fit(
    X_train,
    y_train,
    epochs=400,
    batch_size=10,
    validation_split=0.2,
    callbacks=[checkpoint_weights]
)
# Out:
# Weights will be saved at: D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# Epoch 1/400
# 56/56 [==============================] - ETA: 0s - loss: 2.4492 - accuracy: 0.5000
# Epoch 1: val_loss improved from inf to 1.81550, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 17s 161ms/step - loss: 2.4492 - accuracy: 0.5000 - val_loss: 1.8155 - val_accuracy: 0.5110
# Epoch 2/400
# 56/56 [==============================] - ETA: 0s - loss: 1.7527 - accuracy: 0.5064
# Epoch 2: val_loss improved from 1.81550 to 1.52972, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 164ms/step - loss: 1.7527 - accuracy: 0.5064 - val_loss: 1.5297 - val_accuracy: 0.5260
# Epoch 3/400
# 56/56 [==============================] - ETA: 0s - loss: 1.5501 - accuracy: 0.5148
# Epoch 3: val_loss improved from 1.52972 to 1.45278, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 109ms/step - loss: 1.5501 - accuracy: 0.5148 - val_loss: 1.4528 - val_accuracy: 0.5374
# Epoch 4/400
# 56/56 [==============================] - ETA: 0s - loss: 1.4869 - accuracy: 0.5209
# Epoch 4: val_loss improved from 1.45278 to 1.41763, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 111ms/step - loss: 1.4869 - accuracy: 0.5209 - val_loss: 1.4176 - val_accuracy: 0.5552
# Epoch 5/400
# 56/56 [==============================] - ETA: 0s - loss: 1.4426 - accuracy: 0.5332
# Epoch 5: val_loss improved from 1.41763 to 1.38517, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 110ms/step - loss: 1.4426 - accuracy: 0.5332 - val_loss: 1.3852 - val_accuracy: 0.5536
# Epoch 6/400
# 56/56 [==============================] - ETA: 0s - loss: 1.4037 - accuracy: 0.5399
# Epoch 6: val_loss improved from 1.38517 to 1.35987, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 109ms/step - loss: 1.4037 - accuracy: 0.5399 - val_loss: 1.3599 - val_accuracy: 0.5494
# Epoch 7/400
# 56/56 [==============================] - ETA: 0s - loss: 1.3617 - accuracy: 0.5565
# Epoch 7: val_loss improved from 1.35987 to 1.33684, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 7s 129ms/step - loss: 1.3617 - accuracy: 0.5565 - val_loss: 1.3368 - val_accuracy: 0.5770
# Epoch 8/400
# 56/56 [==============================] - ETA: 0s - loss: 1.3268 - accuracy: 0.5654
# Epoch 8: val_loss improved from 1.33684 to 1.29063, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 110ms/step - loss: 1.3268 - accuracy: 0.5654 - val_loss: 1.2906 - val_accuracy: 0.6002
# Epoch 9/400
# 56/56 [==============================] - ETA: 0s - loss: 1.2915 - accuracy: 0.5799
# Epoch 9: val_loss improved from 1.29063 to 1.26504, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 109ms/step - loss: 1.2915 - accuracy: 0.5799 - val_loss: 1.2650 - val_accuracy: 0.6110
# Epoch 10/400
# 56/56 [==============================] - ETA: 0s - loss: 1.2568 - accuracy: 0.5910
# Epoch 10: val_loss improved from 1.26504 to 1.24060, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 107ms/step - loss: 1.2568 - accuracy: 0.5910 - val_loss: 1.2406 - val_accuracy: 0.6150
# Epoch 11/400
# 56/56 [==============================] - ETA: 0s - loss: 1.2269 - accuracy: 0.6016
# Epoch 11: val_loss improved from 1.24060 to 1.22184, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 106ms/step - loss: 1.2269 - accuracy: 0.6016 - val_loss: 1.2218 - val_accuracy: 0.6203
# Epoch 12/400
# 56/56 [==============================] - ETA: 0s - loss: 1.2044 - accuracy: 0.6051
# Epoch 12: val_loss did not improve from 1.22184
# 56/56 [==============================] - 6s 110ms/step - loss: 1.2044 - accuracy: 0.6051 - val_loss: 1.2313 - val_accuracy: 0.6062
# Epoch 13/400
# 56/56 [==============================] - ETA: 0s - loss: 1.1827 - accuracy: 0.6095
# Epoch 13: val_loss improved from 1.22184 to 1.20579, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 110ms/step - loss: 1.1827 - accuracy: 0.6095 - val_loss: 1.2058 - val_accuracy: 0.6021
# Epoch 14/400
# 56/56 [==============================] - ETA: 0s - loss: 1.1502 - accuracy: 0.6232
# Epoch 14: val_loss improved from 1.20579 to 1.18678, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 112ms/step - loss: 1.1502 - accuracy: 0.6232 - val_loss: 1.1868 - val_accuracy: 0.6342
# Epoch 15/400
# 56/56 [==============================] - ETA: 0s - loss: 1.1386 - accuracy: 0.6292
# Epoch 15: val_loss improved from 1.18678 to 1.17071, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 109ms/step - loss: 1.1386 - accuracy: 0.6292 - val_loss: 1.1707 - val_accuracy: 0.6284
# Epoch 16/400
# 56/56 [==============================] - ETA: 0s - loss: 1.1224 - accuracy: 0.6292
# Epoch 16: val_loss improved from 1.17071 to 1.15521, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 111ms/step - loss: 1.1224 - accuracy: 0.6292 - val_loss: 1.1552 - val_accuracy: 0.6501
# Epoch 17/400
# 56/56 [==============================] - ETA: 0s - loss: 1.0979 - accuracy: 0.6397
# Epoch 17: val_loss improved from 1.15521 to 1.13421, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 10s 173ms/step - loss: 1.0979 - accuracy: 0.6397 - val_loss: 1.1342 - val_accuracy: 0.6397
# Epoch 18/400
# 56/56 [==============================] - ETA: 0s - loss: 1.0744 - accuracy: 0.6431
# Epoch 18: val_loss improved from 1.13421 to 1.13274, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 10s 175ms/step - loss: 1.0744 - accuracy: 0.6431 - val_loss: 1.1327 - val_accuracy: 0.6545
# Epoch 19/400
# 56/56 [==============================] - ETA: 0s - loss: 1.0568 - accuracy: 0.6469
# Epoch 19: val_loss improved from 1.13274 to 1.10241, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 13s 228ms/step - loss: 1.0568 - accuracy: 0.6469 - val_loss: 1.1024 - val_accuracy: 0.6553
# Epoch 20/400
# 56/56 [==============================] - ETA: 0s - loss: 1.0409 - accuracy: 0.6469
# Epoch 20: val_loss did not improve from 1.10241
# 56/56 [==============================] - 13s 235ms/step - loss: 1.0409 - accuracy: 0.6469 - val_loss: 1.1163 - val_accuracy: 0.6507
# Epoch 21/400
# 56/56 [==============================] - ETA: 0s - loss: 1.0337 - accuracy: 0.6500
# Epoch 21: val_loss improved from 1.10241 to 1.08262, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 11s 193ms/step - loss: 1.0337 - accuracy: 0.6500 - val_loss: 1.0826 - val_accuracy: 0.6773
# Epoch 22/400
# 56/56 [==============================] - ETA: 0s - loss: 1.0094 - accuracy: 0.6600
# Epoch 22: val_loss improved from 1.08262 to 1.06740, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 11s 205ms/step - loss: 1.0094 - accuracy: 0.6600 - val_loss: 1.0674 - val_accuracy: 0.6752
# Epoch 23/400
# 56/56 [==============================] - ETA: 0s - loss: 0.9682 - accuracy: 0.6723
# Epoch 23: val_loss improved from 1.06740 to 1.03411, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 11s 199ms/step - loss: 0.9682 - accuracy: 0.6723 - val_loss: 1.0341 - val_accuracy: 0.6888
# Epoch 24/400
# 56/56 [==============================] - ETA: 0s - loss: 0.9409 - accuracy: 0.6846
# Epoch 24: val_loss improved from 1.03411 to 0.99382, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 10s 184ms/step - loss: 0.9409 - accuracy: 0.6846 - val_loss: 0.9938 - val_accuracy: 0.6852
# Epoch 25/400
# 56/56 [==============================] - ETA: 0s - loss: 0.9115 - accuracy: 0.6861
# Epoch 25: val_loss improved from 0.99382 to 0.96804, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 10s 170ms/step - loss: 0.9115 - accuracy: 0.6861 - val_loss: 0.9680 - val_accuracy: 0.6955
# Epoch 26/400
# 56/56 [==============================] - ETA: 0s - loss: 0.8768 - accuracy: 0.7015
# Epoch 26: val_loss improved from 0.96804 to 0.93917, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 12s 206ms/step - loss: 0.8768 - accuracy: 0.7015 - val_loss: 0.9392 - val_accuracy: 0.7019
# Epoch 27/400
# 56/56 [==============================] - ETA: 0s - loss: 0.8439 - accuracy: 0.7110
# Epoch 27: val_loss improved from 0.93917 to 0.89647, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 10s 186ms/step - loss: 0.8439 - accuracy: 0.7110 - val_loss: 0.8965 - val_accuracy: 0.7128
# Epoch 28/400
# 56/56 [==============================] - ETA: 0s - loss: 0.8106 - accuracy: 0.7186
# Epoch 28: val_loss improved from 0.89647 to 0.86737, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 10s 183ms/step - loss: 0.8106 - accuracy: 0.7186 - val_loss: 0.8674 - val_accuracy: 0.7318
# Epoch 29/400
# 56/56 [==============================] - ETA: 0s - loss: 0.7664 - accuracy: 0.7302
# Epoch 29: val_loss improved from 0.86737 to 0.81328, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 161ms/step - loss: 0.7664 - accuracy: 0.7302 - val_loss: 0.8133 - val_accuracy: 0.7513
# Epoch 30/400
# 56/56 [==============================] - ETA: 0s - loss: 0.7275 - accuracy: 0.7424
# Epoch 30: val_loss improved from 0.81328 to 0.77653, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 8s 142ms/step - loss: 0.7275 - accuracy: 0.7424 - val_loss: 0.7765 - val_accuracy: 0.7697
# Epoch 31/400
# 56/56 [==============================] - ETA: 0s - loss: 0.6875 - accuracy: 0.7558
# Epoch 31: val_loss improved from 0.77653 to 0.75593, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 7s 129ms/step - loss: 0.6875 - accuracy: 0.7558 - val_loss: 0.7559 - val_accuracy: 0.7646
# Epoch 32/400
# 56/56 [==============================] - ETA: 0s - loss: 0.6496 - accuracy: 0.7658
# Epoch 32: val_loss improved from 0.75593 to 0.73459, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 157ms/step - loss: 0.6496 - accuracy: 0.7658 - val_loss: 0.7346 - val_accuracy: 0.7770
# Epoch 33/400
# 56/56 [==============================] - ETA: 0s - loss: 0.6287 - accuracy: 0.7718
# Epoch 33: val_loss improved from 0.73459 to 0.71166, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 155ms/step - loss: 0.6287 - accuracy: 0.7718 - val_loss: 0.7117 - val_accuracy: 0.7700
# Epoch 34/400
# 56/56 [==============================] - ETA: 0s - loss: 0.6075 - accuracy: 0.7808
# Epoch 34: val_loss did not improve from 0.71166
# 56/56 [==============================] - 9s 156ms/step - loss: 0.6075 - accuracy: 0.7808 - val_loss: 0.7229 - val_accuracy: 0.7544
# Epoch 35/400
# 56/56 [==============================] - ETA: 0s - loss: 0.5813 - accuracy: 0.7822
# Epoch 35: val_loss improved from 0.71166 to 0.68269, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 153ms/step - loss: 0.5813 - accuracy: 0.7822 - val_loss: 0.6827 - val_accuracy: 0.7706
# Epoch 36/400
# 56/56 [==============================] - ETA: 0s - loss: 0.5606 - accuracy: 0.7932
# Epoch 36: val_loss improved from 0.68269 to 0.66065, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 161ms/step - loss: 0.5606 - accuracy: 0.7932 - val_loss: 0.6606 - val_accuracy: 0.7941
# Epoch 37/400
# 56/56 [==============================] - ETA: 0s - loss: 0.5506 - accuracy: 0.7977
# Epoch 37: val_loss improved from 0.66065 to 0.63873, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 8s 140ms/step - loss: 0.5506 - accuracy: 0.7977 - val_loss: 0.6387 - val_accuracy: 0.8020
# Epoch 38/400
# 56/56 [==============================] - ETA: 0s - loss: 0.5243 - accuracy: 0.8075
# Epoch 38: val_loss improved from 0.63873 to 0.62789, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 156ms/step - loss: 0.5243 - accuracy: 0.8075 - val_loss: 0.6279 - val_accuracy: 0.8049
# Epoch 39/400
# 56/56 [==============================] - ETA: 0s - loss: 0.5150 - accuracy: 0.8112
# Epoch 39: val_loss did not improve from 0.62789
# 56/56 [==============================] - 10s 177ms/step - loss: 0.5150 - accuracy: 0.8112 - val_loss: 0.6323 - val_accuracy: 0.8015
# Epoch 40/400
# 56/56 [==============================] - ETA: 0s - loss: 0.5185 - accuracy: 0.8110
# Epoch 40: val_loss improved from 0.62789 to 0.61955, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 153ms/step - loss: 0.5185 - accuracy: 0.8110 - val_loss: 0.6195 - val_accuracy: 0.8115
# Epoch 41/400
# 56/56 [==============================] - ETA: 0s - loss: 0.4959 - accuracy: 0.8155
# Epoch 41: val_loss improved from 0.61955 to 0.59922, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 161ms/step - loss: 0.4959 - accuracy: 0.8155 - val_loss: 0.5992 - val_accuracy: 0.8134
# Epoch 42/400
# 56/56 [==============================] - ETA: 0s - loss: 0.4775 - accuracy: 0.8211
# Epoch 42: val_loss improved from 0.59922 to 0.58606, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 10s 186ms/step - loss: 0.4775 - accuracy: 0.8211 - val_loss: 0.5861 - val_accuracy: 0.8179
# Epoch 43/400
# 56/56 [==============================] - ETA: 0s - loss: 0.4759 - accuracy: 0.8239
# Epoch 43: val_loss did not improve from 0.58606
# 56/56 [==============================] - 10s 176ms/step - loss: 0.4759 - accuracy: 0.8239 - val_loss: 0.6036 - val_accuracy: 0.7906
# Epoch 44/400
# 56/56 [==============================] - ETA: 0s - loss: 0.4664 - accuracy: 0.8240
# Epoch 44: val_loss improved from 0.58606 to 0.57304, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 158ms/step - loss: 0.4664 - accuracy: 0.8240 - val_loss: 0.5730 - val_accuracy: 0.8148
# Epoch 45/400
# 56/56 [==============================] - ETA: 0s - loss: 0.4502 - accuracy: 0.8333
# Epoch 45: val_loss improved from 0.57304 to 0.55219, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 169ms/step - loss: 0.4502 - accuracy: 0.8333 - val_loss: 0.5522 - val_accuracy: 0.8152
# Epoch 46/400
# 56/56 [==============================] - ETA: 0s - loss: 0.4451 - accuracy: 0.8287
# Epoch 46: val_loss improved from 0.55219 to 0.53805, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 8s 138ms/step - loss: 0.4451 - accuracy: 0.8287 - val_loss: 0.5381 - val_accuracy: 0.8277
# Epoch 47/400
# 56/56 [==============================] - ETA: 0s - loss: 0.4400 - accuracy: 0.8352
# Epoch 47: val_loss did not improve from 0.53805
# 56/56 [==============================] - 8s 136ms/step - loss: 0.4400 - accuracy: 0.8352 - val_loss: 0.5423 - val_accuracy: 0.8269
# Epoch 48/400
# 56/56 [==============================] - ETA: 0s - loss: 0.4306 - accuracy: 0.8366
# Epoch 48: val_loss did not improve from 0.53805
# 56/56 [==============================] - 9s 156ms/step - loss: 0.4306 - accuracy: 0.8366 - val_loss: 0.5451 - val_accuracy: 0.8228
# Epoch 49/400
# 56/56 [==============================] - ETA: 0s - loss: 0.4154 - accuracy: 0.8429
# Epoch 49: val_loss did not improve from 0.53805
# 56/56 [==============================] - 8s 143ms/step - loss: 0.4154 - accuracy: 0.8429 - val_loss: 0.5465 - val_accuracy: 0.8225
# Epoch 50/400
# 56/56 [==============================] - ETA: 0s - loss: 0.4108 - accuracy: 0.8471
# Epoch 50: val_loss improved from 0.53805 to 0.52620, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 7s 130ms/step - loss: 0.4108 - accuracy: 0.8471 - val_loss: 0.5262 - val_accuracy: 0.8333
# Epoch 51/400
# 56/56 [==============================] - ETA: 0s - loss: 0.4068 - accuracy: 0.8422
# Epoch 51: val_loss improved from 0.52620 to 0.51926, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 8s 146ms/step - loss: 0.4068 - accuracy: 0.8422 - val_loss: 0.5193 - val_accuracy: 0.8359
# Epoch 52/400
# 56/56 [==============================] - ETA: 0s - loss: 0.4014 - accuracy: 0.8434
# Epoch 52: val_loss did not improve from 0.51926
# 56/56 [==============================] - 8s 138ms/step - loss: 0.4014 - accuracy: 0.8434 - val_loss: 0.5282 - val_accuracy: 0.8321
# Epoch 53/400
# 56/56 [==============================] - ETA: 0s - loss: 0.4045 - accuracy: 0.8447
# Epoch 53: val_loss improved from 0.51926 to 0.51076, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 162ms/step - loss: 0.4045 - accuracy: 0.8447 - val_loss: 0.5108 - val_accuracy: 0.8277
# Epoch 54/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3893 - accuracy: 0.8463
# Epoch 54: val_loss did not improve from 0.51076
# 56/56 [==============================] - 8s 144ms/step - loss: 0.3893 - accuracy: 0.8463 - val_loss: 0.5182 - val_accuracy: 0.8347
# Epoch 55/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3836 - accuracy: 0.8477
# Epoch 55: val_loss improved from 0.51076 to 0.49682, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 8s 136ms/step - loss: 0.3836 - accuracy: 0.8477 - val_loss: 0.4968 - val_accuracy: 0.8360
# Epoch 56/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3771 - accuracy: 0.8509
# Epoch 56: val_loss improved from 0.49682 to 0.49597, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 165ms/step - loss: 0.3771 - accuracy: 0.8509 - val_loss: 0.4960 - val_accuracy: 0.8340
# Epoch 57/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3696 - accuracy: 0.8584
# Epoch 57: val_loss improved from 0.49597 to 0.47253, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 7s 132ms/step - loss: 0.3696 - accuracy: 0.8584 - val_loss: 0.4725 - val_accuracy: 0.8398
# Epoch 58/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3714 - accuracy: 0.8507
# Epoch 58: val_loss did not improve from 0.47253
# 56/56 [==============================] - 7s 133ms/step - loss: 0.3714 - accuracy: 0.8507 - val_loss: 0.4848 - val_accuracy: 0.8376
# Epoch 59/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3640 - accuracy: 0.8563
# Epoch 59: val_loss did not improve from 0.47253
# 56/56 [==============================] - 10s 171ms/step - loss: 0.3640 - accuracy: 0.8563 - val_loss: 0.4754 - val_accuracy: 0.8400
# Epoch 60/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3566 - accuracy: 0.8601
# Epoch 60: val_loss improved from 0.47253 to 0.47120, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 9s 167ms/step - loss: 0.3566 - accuracy: 0.8601 - val_loss: 0.4712 - val_accuracy: 0.8430
# Epoch 61/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3545 - accuracy: 0.8613
# Epoch 61: val_loss did not improve from 0.47120
# 56/56 [==============================] - 8s 139ms/step - loss: 0.3545 - accuracy: 0.8613 - val_loss: 0.4821 - val_accuracy: 0.8411
# Epoch 62/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3567 - accuracy: 0.8574
# Epoch 62: val_loss improved from 0.47120 to 0.46574, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 8s 143ms/step - loss: 0.3567 - accuracy: 0.8574 - val_loss: 0.4657 - val_accuracy: 0.8472
# Epoch 63/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3438 - accuracy: 0.8644
# Epoch 63: val_loss did not improve from 0.46574
# 56/56 [==============================] - 8s 148ms/step - loss: 0.3438 - accuracy: 0.8644 - val_loss: 0.4956 - val_accuracy: 0.8233
# Epoch 64/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3396 - accuracy: 0.8631
# Epoch 64: val_loss did not improve from 0.46574
# 56/56 [==============================] - 8s 146ms/step - loss: 0.3396 - accuracy: 0.8631 - val_loss: 0.4714 - val_accuracy: 0.8360
# Epoch 65/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3383 - accuracy: 0.8637
# Epoch 65: val_loss did not improve from 0.46574
# 56/56 [==============================] - 8s 144ms/step - loss: 0.3383 - accuracy: 0.8637 - val_loss: 0.4733 - val_accuracy: 0.8272
# Epoch 66/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3349 - accuracy: 0.8663
# Epoch 66: val_loss improved from 0.46574 to 0.44687, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 8s 144ms/step - loss: 0.3349 - accuracy: 0.8663 - val_loss: 0.4469 - val_accuracy: 0.8480
# Epoch 67/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3359 - accuracy: 0.8671
# Epoch 67: val_loss did not improve from 0.44687
# 56/56 [==============================] - 8s 147ms/step - loss: 0.3359 - accuracy: 0.8671 - val_loss: 0.4537 - val_accuracy: 0.8515
# Epoch 68/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3277 - accuracy: 0.8685
# Epoch 68: val_loss did not improve from 0.44687
# 56/56 [==============================] - 9s 156ms/step - loss: 0.3277 - accuracy: 0.8685 - val_loss: 0.4540 - val_accuracy: 0.8390
# Epoch 69/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3319 - accuracy: 0.8639
# Epoch 69: val_loss improved from 0.44687 to 0.43902, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 8s 150ms/step - loss: 0.3319 - accuracy: 0.8639 - val_loss: 0.4390 - val_accuracy: 0.8512
# Epoch 70/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3228 - accuracy: 0.8692
# Epoch 70: val_loss improved from 0.43902 to 0.43305, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 8s 142ms/step - loss: 0.3228 - accuracy: 0.8692 - val_loss: 0.4331 - val_accuracy: 0.8567
# Epoch 71/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3190 - accuracy: 0.8681
# Epoch 71: val_loss improved from 0.43305 to 0.42983, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 8s 150ms/step - loss: 0.3190 - accuracy: 0.8681 - val_loss: 0.4298 - val_accuracy: 0.8471
# Epoch 72/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3173 - accuracy: 0.8674
# Epoch 72: val_loss did not improve from 0.42983
# 56/56 [==============================] - 8s 143ms/step - loss: 0.3173 - accuracy: 0.8674 - val_loss: 0.4542 - val_accuracy: 0.8359
# Epoch 73/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3211 - accuracy: 0.8715
# Epoch 73: val_loss did not improve from 0.42983
# 56/56 [==============================] - 8s 135ms/step - loss: 0.3211 - accuracy: 0.8715 - val_loss: 0.4312 - val_accuracy: 0.8528
# Epoch 74/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3103 - accuracy: 0.8718
# Epoch 74: val_loss improved from 0.42983 to 0.42108, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 7s 126ms/step - loss: 0.3103 - accuracy: 0.8718 - val_loss: 0.4211 - val_accuracy: 0.8487
# Epoch 75/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3070 - accuracy: 0.8719
# Epoch 75: val_loss did not improve from 0.42108
# 56/56 [==============================] - 7s 118ms/step - loss: 0.3070 - accuracy: 0.8719 - val_loss: 0.4341 - val_accuracy: 0.8423
# Epoch 76/400
# 56/56 [==============================] - ETA: 0s - loss: 0.3017 - accuracy: 0.8739
# Epoch 76: val_loss improved from 0.42108 to 0.41475, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 7s 117ms/step - loss: 0.3017 - accuracy: 0.8739 - val_loss: 0.4148 - val_accuracy: 0.8566
# Epoch 77/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2976 - accuracy: 0.8771
# Epoch 77: val_loss improved from 0.41475 to 0.40970, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 7s 118ms/step - loss: 0.2976 - accuracy: 0.8771 - val_loss: 0.4097 - val_accuracy: 0.8592
# Epoch 78/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.8759
# Epoch 78: val_loss did not improve from 0.40970
# 56/56 [==============================] - 7s 117ms/step - loss: 0.2960 - accuracy: 0.8759 - val_loss: 0.4116 - val_accuracy: 0.8528
# Epoch 79/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2907 - accuracy: 0.8774
# Epoch 79: val_loss did not improve from 0.40970
# 56/56 [==============================] - 7s 118ms/step - loss: 0.2907 - accuracy: 0.8774 - val_loss: 0.4174 - val_accuracy: 0.8525
# Epoch 80/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2903 - accuracy: 0.8772
# Epoch 80: val_loss did not improve from 0.40970
# 56/56 [==============================] - 7s 130ms/step - loss: 0.2903 - accuracy: 0.8772 - val_loss: 0.4320 - val_accuracy: 0.8465
# Epoch 81/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2876 - accuracy: 0.8761
# Epoch 81: val_loss improved from 0.40970 to 0.40693, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 7s 125ms/step - loss: 0.2876 - accuracy: 0.8761 - val_loss: 0.4069 - val_accuracy: 0.8569
# Epoch 82/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2884 - accuracy: 0.8809
# Epoch 82: val_loss did not improve from 0.40693
# 56/56 [==============================] - 7s 122ms/step - loss: 0.2884 - accuracy: 0.8809 - val_loss: 0.4143 - val_accuracy: 0.8589
# Epoch 83/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2857 - accuracy: 0.8786
# Epoch 83: val_loss did not improve from 0.40693
# 56/56 [==============================] - 7s 127ms/step - loss: 0.2857 - accuracy: 0.8786 - val_loss: 0.4166 - val_accuracy: 0.8507
# Epoch 84/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2868 - accuracy: 0.8775
# Epoch 84: val_loss improved from 0.40693 to 0.40183, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 7s 127ms/step - loss: 0.2868 - accuracy: 0.8775 - val_loss: 0.4018 - val_accuracy: 0.8603
# Epoch 85/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2802 - accuracy: 0.8802
# Epoch 85: val_loss improved from 0.40183 to 0.39981, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 7s 128ms/step - loss: 0.2802 - accuracy: 0.8802 - val_loss: 0.3998 - val_accuracy: 0.8609
# Epoch 86/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2795 - accuracy: 0.8823
# Epoch 86: val_loss did not improve from 0.39981
# 56/56 [==============================] - 7s 125ms/step - loss: 0.2795 - accuracy: 0.8823 - val_loss: 0.4076 - val_accuracy: 0.8512
# Epoch 87/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2748 - accuracy: 0.8804
# Epoch 87: val_loss improved from 0.39981 to 0.39591, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 115ms/step - loss: 0.2748 - accuracy: 0.8804 - val_loss: 0.3959 - val_accuracy: 0.8605
# Epoch 88/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2723 - accuracy: 0.8816
# Epoch 88: val_loss did not improve from 0.39591
# 56/56 [==============================] - 6s 115ms/step - loss: 0.2723 - accuracy: 0.8816 - val_loss: 0.4083 - val_accuracy: 0.8559
# Epoch 89/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.8820
# Epoch 89: val_loss improved from 0.39591 to 0.39295, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 115ms/step - loss: 0.2693 - accuracy: 0.8820 - val_loss: 0.3930 - val_accuracy: 0.8624
# Epoch 90/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.8817
# Epoch 90: val_loss did not improve from 0.39295
# 56/56 [==============================] - 7s 118ms/step - loss: 0.2693 - accuracy: 0.8817 - val_loss: 0.3936 - val_accuracy: 0.8624
# Epoch 91/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2691 - accuracy: 0.8825
# Epoch 91: val_loss improved from 0.39295 to 0.38469, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 7s 124ms/step - loss: 0.2691 - accuracy: 0.8825 - val_loss: 0.3847 - val_accuracy: 0.8647
# Epoch 92/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2651 - accuracy: 0.8827
# Epoch 92: val_loss did not improve from 0.38469
# 56/56 [==============================] - 7s 118ms/step - loss: 0.2651 - accuracy: 0.8827 - val_loss: 0.3933 - val_accuracy: 0.8581
# Epoch 93/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.8830
# Epoch 93: val_loss did not improve from 0.38469
# 56/56 [==============================] - 6s 108ms/step - loss: 0.2646 - accuracy: 0.8830 - val_loss: 0.3902 - val_accuracy: 0.8602
# Epoch 94/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2612 - accuracy: 0.8841
# Epoch 94: val_loss did not improve from 0.38469
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2612 - accuracy: 0.8841 - val_loss: 0.3922 - val_accuracy: 0.8636
# Epoch 95/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2607 - accuracy: 0.8856
# Epoch 95: val_loss did not improve from 0.38469
# 56/56 [==============================] - 6s 107ms/step - loss: 0.2607 - accuracy: 0.8856 - val_loss: 0.3904 - val_accuracy: 0.8638
# Epoch 96/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.8848
# Epoch 96: val_loss did not improve from 0.38469
# 56/56 [==============================] - 6s 105ms/step - loss: 0.2565 - accuracy: 0.8848 - val_loss: 0.3904 - val_accuracy: 0.8653
# Epoch 97/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2543 - accuracy: 0.8858
# Epoch 97: val_loss did not improve from 0.38469
# 56/56 [==============================] - 6s 107ms/step - loss: 0.2543 - accuracy: 0.8858 - val_loss: 0.4063 - val_accuracy: 0.8550
# Epoch 98/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2564 - accuracy: 0.8863
# Epoch 98: val_loss did not improve from 0.38469
# 56/56 [==============================] - 6s 104ms/step - loss: 0.2564 - accuracy: 0.8863 - val_loss: 0.3976 - val_accuracy: 0.8626
# Epoch 99/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2522 - accuracy: 0.8883
# Epoch 99: val_loss did not improve from 0.38469
# 56/56 [==============================] - 6s 105ms/step - loss: 0.2522 - accuracy: 0.8883 - val_loss: 0.3908 - val_accuracy: 0.8641
# Epoch 100/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2577 - accuracy: 0.8854
# Epoch 100: val_loss did not improve from 0.38469
# 56/56 [==============================] - 6s 107ms/step - loss: 0.2577 - accuracy: 0.8854 - val_loss: 0.4071 - val_accuracy: 0.8461
# Epoch 101/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2566 - accuracy: 0.8843
# Epoch 101: val_loss did not improve from 0.38469
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2566 - accuracy: 0.8843 - val_loss: 0.3910 - val_accuracy: 0.8673
# Epoch 102/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2457 - accuracy: 0.8892
# Epoch 102: val_loss improved from 0.38469 to 0.38453, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 111ms/step - loss: 0.2457 - accuracy: 0.8892 - val_loss: 0.3845 - val_accuracy: 0.8647
# Epoch 103/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2448 - accuracy: 0.8904
# Epoch 103: val_loss improved from 0.38453 to 0.38420, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 105ms/step - loss: 0.2448 - accuracy: 0.8904 - val_loss: 0.3842 - val_accuracy: 0.8652
# Epoch 104/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2514 - accuracy: 0.8884
# Epoch 104: val_loss improved from 0.38420 to 0.38316, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2514 - accuracy: 0.8884 - val_loss: 0.3832 - val_accuracy: 0.8653
# Epoch 105/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2426 - accuracy: 0.8897
# Epoch 105: val_loss improved from 0.38316 to 0.37726, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 108ms/step - loss: 0.2426 - accuracy: 0.8897 - val_loss: 0.3773 - val_accuracy: 0.8639
# Epoch 106/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2448 - accuracy: 0.8902
# Epoch 106: val_loss did not improve from 0.37726
# 56/56 [==============================] - 6s 103ms/step - loss: 0.2448 - accuracy: 0.8902 - val_loss: 0.3848 - val_accuracy: 0.8560
# Epoch 107/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2418 - accuracy: 0.8902
# Epoch 107: val_loss improved from 0.37726 to 0.37310, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 107ms/step - loss: 0.2418 - accuracy: 0.8902 - val_loss: 0.3731 - val_accuracy: 0.8696
# Epoch 108/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2360 - accuracy: 0.8908
# Epoch 108: val_loss improved from 0.37310 to 0.37004, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 109ms/step - loss: 0.2360 - accuracy: 0.8908 - val_loss: 0.3700 - val_accuracy: 0.8648
# Epoch 109/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2366 - accuracy: 0.8912
# Epoch 109: val_loss did not improve from 0.37004
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2366 - accuracy: 0.8912 - val_loss: 0.3744 - val_accuracy: 0.8653
# Epoch 110/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2349 - accuracy: 0.8941
# Epoch 110: val_loss did not improve from 0.37004
# 56/56 [==============================] - 6s 103ms/step - loss: 0.2349 - accuracy: 0.8941 - val_loss: 0.3747 - val_accuracy: 0.8708
# Epoch 111/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.8925
# Epoch 111: val_loss improved from 0.37004 to 0.36087, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 107ms/step - loss: 0.2346 - accuracy: 0.8925 - val_loss: 0.3609 - val_accuracy: 0.8734
# Epoch 112/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2335 - accuracy: 0.8932
# Epoch 112: val_loss improved from 0.36087 to 0.36008, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 107ms/step - loss: 0.2335 - accuracy: 0.8932 - val_loss: 0.3601 - val_accuracy: 0.8726
# Epoch 113/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2391 - accuracy: 0.8931
# Epoch 113: val_loss did not improve from 0.36008
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2391 - accuracy: 0.8931 - val_loss: 0.4328 - val_accuracy: 0.8402
# Epoch 114/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2348 - accuracy: 0.8922
# Epoch 114: val_loss did not improve from 0.36008
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2348 - accuracy: 0.8922 - val_loss: 0.3602 - val_accuracy: 0.8738
# Epoch 115/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2263 - accuracy: 0.8947
# Epoch 115: val_loss did not improve from 0.36008
# 56/56 [==============================] - 6s 107ms/step - loss: 0.2263 - accuracy: 0.8947 - val_loss: 0.3720 - val_accuracy: 0.8589
# Epoch 116/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2227 - accuracy: 0.8935
# Epoch 116: val_loss did not improve from 0.36008
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2227 - accuracy: 0.8935 - val_loss: 0.3605 - val_accuracy: 0.8713
# Epoch 117/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2229 - accuracy: 0.8927
# Epoch 117: val_loss did not improve from 0.36008
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2229 - accuracy: 0.8927 - val_loss: 0.3619 - val_accuracy: 0.8678
# Epoch 118/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2212 - accuracy: 0.8951
# Epoch 118: val_loss did not improve from 0.36008
# 56/56 [==============================] - 6s 102ms/step - loss: 0.2212 - accuracy: 0.8951 - val_loss: 0.3633 - val_accuracy: 0.8682
# Epoch 119/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2185 - accuracy: 0.8955
# Epoch 119: val_loss did not improve from 0.36008
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2185 - accuracy: 0.8955 - val_loss: 0.3641 - val_accuracy: 0.8675
# Epoch 120/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2179 - accuracy: 0.8964
# Epoch 120: val_loss improved from 0.36008 to 0.35773, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 113ms/step - loss: 0.2179 - accuracy: 0.8964 - val_loss: 0.3577 - val_accuracy: 0.8667
# Epoch 121/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.8968
# Epoch 121: val_loss did not improve from 0.35773
# 56/56 [==============================] - 6s 108ms/step - loss: 0.2175 - accuracy: 0.8968 - val_loss: 0.3629 - val_accuracy: 0.8615
# Epoch 122/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.8952
# Epoch 122: val_loss improved from 0.35773 to 0.35703, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 109ms/step - loss: 0.2187 - accuracy: 0.8952 - val_loss: 0.3570 - val_accuracy: 0.8599
# Epoch 123/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2151 - accuracy: 0.8951
# Epoch 123: val_loss improved from 0.35703 to 0.34730, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 107ms/step - loss: 0.2151 - accuracy: 0.8951 - val_loss: 0.3473 - val_accuracy: 0.8720
# Epoch 124/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.8976
# Epoch 124: val_loss did not improve from 0.34730
# 56/56 [==============================] - 6s 103ms/step - loss: 0.2117 - accuracy: 0.8976 - val_loss: 0.3519 - val_accuracy: 0.8747
# Epoch 125/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2151 - accuracy: 0.8963
# Epoch 125: val_loss did not improve from 0.34730
# 56/56 [==============================] - 6s 107ms/step - loss: 0.2151 - accuracy: 0.8963 - val_loss: 0.3476 - val_accuracy: 0.8781
# Epoch 126/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2134 - accuracy: 0.8976
# Epoch 126: val_loss improved from 0.34730 to 0.34611, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 108ms/step - loss: 0.2134 - accuracy: 0.8976 - val_loss: 0.3461 - val_accuracy: 0.8744
# Epoch 127/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2096 - accuracy: 0.8959
# Epoch 127: val_loss improved from 0.34611 to 0.34593, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2096 - accuracy: 0.8959 - val_loss: 0.3459 - val_accuracy: 0.8779
# Epoch 128/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2069 - accuracy: 0.8977
# Epoch 128: val_loss did not improve from 0.34593
# 56/56 [==============================] - 6s 108ms/step - loss: 0.2069 - accuracy: 0.8977 - val_loss: 0.3607 - val_accuracy: 0.8652
# Epoch 129/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2102 - accuracy: 0.8968
# Epoch 129: val_loss did not improve from 0.34593
# 56/56 [==============================] - 6s 111ms/step - loss: 0.2102 - accuracy: 0.8968 - val_loss: 0.3514 - val_accuracy: 0.8680
# Epoch 130/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2066 - accuracy: 0.8986
# Epoch 130: val_loss improved from 0.34593 to 0.34473, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 108ms/step - loss: 0.2066 - accuracy: 0.8986 - val_loss: 0.3447 - val_accuracy: 0.8751
# Epoch 131/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2039 - accuracy: 0.8991
# Epoch 131: val_loss improved from 0.34473 to 0.34432, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2039 - accuracy: 0.8991 - val_loss: 0.3443 - val_accuracy: 0.8695
# Epoch 132/400
# 56/56 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9020
# Epoch 132: val_loss improved from 0.34432 to 0.33810, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 107ms/step - loss: 0.1988 - accuracy: 0.9020 - val_loss: 0.3381 - val_accuracy: 0.8753
# Epoch 133/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2026 - accuracy: 0.9002
# Epoch 133: val_loss did not improve from 0.33810
# 56/56 [==============================] - 6s 103ms/step - loss: 0.2026 - accuracy: 0.9002 - val_loss: 0.3499 - val_accuracy: 0.8714
# Epoch 134/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2003 - accuracy: 0.9013
# Epoch 134: val_loss improved from 0.33810 to 0.33580, saving model to D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights\audio_visual_yes_no_part2.h5
# 56/56 [==============================] - 6s 107ms/step - loss: 0.2003 - accuracy: 0.9013 - val_loss: 0.3358 - val_accuracy: 0.8782
# Epoch 135/400
# 56/56 [==============================] - ETA: 0s - loss: 0.1977 - accuracy: 0.8987
# Epoch 135: val_loss did not improve from 0.33580
# 56/56 [==============================] - 6s 105ms/step - loss: 0.1977 - accuracy: 0.8987 - val_loss: 0.3467 - val_accuracy: 0.8705
# Epoch 136/400
# 56/56 [==============================] - ETA: 0s - loss: 0.2000 - accuracy: 0.9003
# Epoch 136: val_loss did not improve from 0.33580
# 56/56 [==============================] - 6s 105ms/step - loss: 0.2000 - accuracy: 0.9003 - val_loss: 0.3427 - val_accuracy: 0.8723
# Epoch 137/400
# 56/56 [==============================] - ETA: 0s - loss: 0.1962 - accuracy: 0.9010
# Epoch 137: val_loss did not improve from 0.33580
# 56/56 [==============================] - 6s 104ms/step - loss: 0.1962 - accuracy: 0.9010 - val_loss: 0.3367 - val_accuracy: 0.8780
# Epoch 138/400
# ...
# Epoch 343: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 128ms/step - loss: 0.0904 - accuracy: 0.9283 - val_loss: 0.2513 - val_accuracy: 0.8901
# Epoch 344/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9274
# Epoch 344: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 131ms/step - loss: 0.0912 - accuracy: 0.9274 - val_loss: 0.2587 - val_accuracy: 0.8872
# Epoch 345/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9278
# Epoch 345: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 129ms/step - loss: 0.0909 - accuracy: 0.9278 - val_loss: 0.2585 - val_accuracy: 0.8839
# Epoch 346/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9287
# Epoch 346: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 126ms/step - loss: 0.0918 - accuracy: 0.9287 - val_loss: 0.2432 - val_accuracy: 0.8927
# Epoch 347/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9291
# Epoch 347: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 128ms/step - loss: 0.0928 - accuracy: 0.9291 - val_loss: 0.2568 - val_accuracy: 0.8867
# Epoch 348/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9265
# Epoch 348: val_loss did not improve from 0.23732
# 56/56 [==============================] - 8s 140ms/step - loss: 0.0900 - accuracy: 0.9265 - val_loss: 0.2494 - val_accuracy: 0.8896
# Epoch 349/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0888 - accuracy: 0.9279
# Epoch 349: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 125ms/step - loss: 0.0888 - accuracy: 0.9279 - val_loss: 0.2442 - val_accuracy: 0.8875
# Epoch 350/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.9295
# Epoch 350: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 127ms/step - loss: 0.0887 - accuracy: 0.9295 - val_loss: 0.2621 - val_accuracy: 0.8848
# Epoch 351/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0893 - accuracy: 0.9289
# Epoch 351: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 126ms/step - loss: 0.0893 - accuracy: 0.9289 - val_loss: 0.2458 - val_accuracy: 0.8910
# Epoch 352/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9274
# Epoch 352: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 124ms/step - loss: 0.0898 - accuracy: 0.9274 - val_loss: 0.2576 - val_accuracy: 0.8855
# Epoch 353/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0908 - accuracy: 0.9275
# Epoch 353: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 124ms/step - loss: 0.0908 - accuracy: 0.9275 - val_loss: 0.2494 - val_accuracy: 0.8830
# Epoch 354/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0877 - accuracy: 0.9288
# Epoch 354: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 125ms/step - loss: 0.0877 - accuracy: 0.9288 - val_loss: 0.2702 - val_accuracy: 0.8804
# Epoch 355/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.9268
# Epoch 355: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 123ms/step - loss: 0.0902 - accuracy: 0.9268 - val_loss: 0.2514 - val_accuracy: 0.8881
# Epoch 356/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9288
# Epoch 356: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 120ms/step - loss: 0.0883 - accuracy: 0.9288 - val_loss: 0.2548 - val_accuracy: 0.8867
# Epoch 357/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9279
# Epoch 357: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 123ms/step - loss: 0.0865 - accuracy: 0.9279 - val_loss: 0.2460 - val_accuracy: 0.8876
# Epoch 358/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9273
# Epoch 358: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 118ms/step - loss: 0.0881 - accuracy: 0.9273 - val_loss: 0.2482 - val_accuracy: 0.8899
# Epoch 359/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9272
# Epoch 359: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 119ms/step - loss: 0.0862 - accuracy: 0.9272 - val_loss: 0.2524 - val_accuracy: 0.8871
# Epoch 360/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0874 - accuracy: 0.9289
# Epoch 360: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 126ms/step - loss: 0.0874 - accuracy: 0.9289 - val_loss: 0.2597 - val_accuracy: 0.8847
# Epoch 361/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0860 - accuracy: 0.9290
# Epoch 361: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 122ms/step - loss: 0.0860 - accuracy: 0.9290 - val_loss: 0.2535 - val_accuracy: 0.8860
# Epoch 362/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0869 - accuracy: 0.9273
# Epoch 362: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 123ms/step - loss: 0.0869 - accuracy: 0.9273 - val_loss: 0.2626 - val_accuracy: 0.8791
# Epoch 363/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9277
# Epoch 363: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 122ms/step - loss: 0.0878 - accuracy: 0.9277 - val_loss: 0.2444 - val_accuracy: 0.8849
# Epoch 364/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9275
# Epoch 364: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 125ms/step - loss: 0.0885 - accuracy: 0.9275 - val_loss: 0.2646 - val_accuracy: 0.8810
# Epoch 365/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0882 - accuracy: 0.9278
# Epoch 365: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 119ms/step - loss: 0.0882 - accuracy: 0.9278 - val_loss: 0.2643 - val_accuracy: 0.8778
# Epoch 366/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0861 - accuracy: 0.9295
# Epoch 366: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 119ms/step - loss: 0.0861 - accuracy: 0.9295 - val_loss: 0.2643 - val_accuracy: 0.8778
# Epoch 367/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0864 - accuracy: 0.9291
# Epoch 367: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 120ms/step - loss: 0.0864 - accuracy: 0.9291 - val_loss: 0.2590 - val_accuracy: 0.8840
# Epoch 368/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 0.9279
# Epoch 368: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 121ms/step - loss: 0.0856 - accuracy: 0.9279 - val_loss: 0.2566 - val_accuracy: 0.8811
# Epoch 369/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.9286
# Epoch 369: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 117ms/step - loss: 0.0841 - accuracy: 0.9286 - val_loss: 0.2513 - val_accuracy: 0.8829
# Epoch 370/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9283
# Epoch 370: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 118ms/step - loss: 0.0853 - accuracy: 0.9283 - val_loss: 0.2516 - val_accuracy: 0.8883
# Epoch 371/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9310
# Epoch 371: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 118ms/step - loss: 0.0844 - accuracy: 0.9310 - val_loss: 0.2454 - val_accuracy: 0.8856
# Epoch 372/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.9298
# Epoch 372: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 121ms/step - loss: 0.0841 - accuracy: 0.9298 - val_loss: 0.2594 - val_accuracy: 0.8787
# Epoch 373/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9316
# Epoch 373: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 121ms/step - loss: 0.0844 - accuracy: 0.9316 - val_loss: 0.2530 - val_accuracy: 0.8853
# Epoch 374/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0836 - accuracy: 0.9311
# Epoch 374: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 122ms/step - loss: 0.0836 - accuracy: 0.9311 - val_loss: 0.2570 - val_accuracy: 0.8816
# Epoch 375/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9288
# Epoch 375: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 122ms/step - loss: 0.0855 - accuracy: 0.9288 - val_loss: 0.2497 - val_accuracy: 0.8901
# Epoch 376/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9277
# Epoch 376: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 120ms/step - loss: 0.0884 - accuracy: 0.9277 - val_loss: 0.2464 - val_accuracy: 0.8866
# Epoch 377/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0867 - accuracy: 0.9286
# Epoch 377: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 120ms/step - loss: 0.0867 - accuracy: 0.9286 - val_loss: 0.2533 - val_accuracy: 0.8803
# Epoch 378/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9294
# Epoch 378: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 117ms/step - loss: 0.0859 - accuracy: 0.9294 - val_loss: 0.2465 - val_accuracy: 0.8854
# Epoch 379/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0852 - accuracy: 0.9285
# Epoch 379: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 123ms/step - loss: 0.0852 - accuracy: 0.9285 - val_loss: 0.2446 - val_accuracy: 0.8857
# Epoch 380/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9294
# Epoch 380: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 127ms/step - loss: 0.0845 - accuracy: 0.9294 - val_loss: 0.2592 - val_accuracy: 0.8820
# Epoch 381/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0833 - accuracy: 0.9301
# Epoch 381: val_loss did not improve from 0.23732
# 56/56 [==============================] - 8s 134ms/step - loss: 0.0833 - accuracy: 0.9301 - val_loss: 0.2583 - val_accuracy: 0.8807
# Epoch 382/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0854 - accuracy: 0.9284
# Epoch 382: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 119ms/step - loss: 0.0854 - accuracy: 0.9284 - val_loss: 0.2496 - val_accuracy: 0.8858
# Epoch 383/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9297
# Epoch 383: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 120ms/step - loss: 0.0837 - accuracy: 0.9297 - val_loss: 0.2578 - val_accuracy: 0.8854
# Epoch 384/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0830 - accuracy: 0.9305
# Epoch 384: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 125ms/step - loss: 0.0830 - accuracy: 0.9305 - val_loss: 0.2539 - val_accuracy: 0.8844
# Epoch 385/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0835 - accuracy: 0.9300
# Epoch 385: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 120ms/step - loss: 0.0835 - accuracy: 0.9300 - val_loss: 0.2811 - val_accuracy: 0.8799
# Epoch 386/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0875 - accuracy: 0.9297
# Epoch 386: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 121ms/step - loss: 0.0875 - accuracy: 0.9297 - val_loss: 0.2597 - val_accuracy: 0.8817
# Epoch 387/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9278
# Epoch 387: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 123ms/step - loss: 0.0848 - accuracy: 0.9278 - val_loss: 0.2450 - val_accuracy: 0.8843
# Epoch 388/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0830 - accuracy: 0.9290
# Epoch 388: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 120ms/step - loss: 0.0830 - accuracy: 0.9290 - val_loss: 0.2474 - val_accuracy: 0.8848
# Epoch 389/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0835 - accuracy: 0.9300
# Epoch 389: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 118ms/step - loss: 0.0835 - accuracy: 0.9300 - val_loss: 0.2555 - val_accuracy: 0.8859
# Epoch 390/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9293
# Epoch 390: val_loss did not improve from 0.23732
# 56/56 [==============================] - 8s 135ms/step - loss: 0.0825 - accuracy: 0.9293 - val_loss: 0.2508 - val_accuracy: 0.8878
# Epoch 391/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0832 - accuracy: 0.9290
# Epoch 391: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 124ms/step - loss: 0.0832 - accuracy: 0.9290 - val_loss: 0.2491 - val_accuracy: 0.8879
# Epoch 392/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9323
# Epoch 392: val_loss did not improve from 0.23732
# 56/56 [==============================] - 7s 121ms/step - loss: 0.0822 - accuracy: 0.9323 - val_loss: 0.2827 - val_accuracy: 0.8742
# Epoch 393/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0833 - accuracy: 0.9291
# Epoch 393: val_loss did not improve from 0.23732
# 56/56 [==============================] - 8s 148ms/step - loss: 0.0833 - accuracy: 0.9291 - val_loss: 0.2809 - val_accuracy: 0.8787
# Epoch 394/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9307
# Epoch 394: val_loss did not improve from 0.23732
# 56/56 [==============================] - 11s 203ms/step - loss: 0.0848 - accuracy: 0.9307 - val_loss: 0.2578 - val_accuracy: 0.8809
# Epoch 395/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9314
# Epoch 395: val_loss did not improve from 0.23732
# 56/56 [==============================] - 11s 194ms/step - loss: 0.0815 - accuracy: 0.9314 - val_loss: 0.2590 - val_accuracy: 0.8815
# Epoch 396/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0808 - accuracy: 0.9302
# Epoch 396: val_loss did not improve from 0.23732
# 56/56 [==============================] - 12s 207ms/step - loss: 0.0808 - accuracy: 0.9302 - val_loss: 0.2612 - val_accuracy: 0.8828
# Epoch 397/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0834 - accuracy: 0.9298
# Epoch 397: val_loss did not improve from 0.23732
# 56/56 [==============================] - 11s 201ms/step - loss: 0.0834 - accuracy: 0.9298 - val_loss: 0.2676 - val_accuracy: 0.8831
# Epoch 398/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0814 - accuracy: 0.9309
# Epoch 398: val_loss did not improve from 0.23732
# 56/56 [==============================] - 11s 204ms/step - loss: 0.0814 - accuracy: 0.9309 - val_loss: 0.2486 - val_accuracy: 0.8784
# Epoch 399/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0826 - accuracy: 0.9305
# Epoch 399: val_loss did not improve from 0.23732
# 56/56 [==============================] - 11s 202ms/step - loss: 0.0826 - accuracy: 0.9305 - val_loss: 0.2544 - val_accuracy: 0.8850
# Epoch 400/400
# 56/56 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9303
# Epoch 400: val_loss did not improve from 0.23732
# 56/56 [==============================] - 12s 206ms/step - loss: 0.0817 - accuracy: 0.9303 - val_loss: 0.2451 - val_accuracy: 0.8839

# %%
# Loss curve
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history_linear_4.history['loss'], label='Training Loss')
plt.plot(history_linear_4.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)

# Accuracy curve
plt.subplot(1,2,2)
plt.plot(history_linear_4.history['accuracy'], label='Training Accuracy')
plt.plot(history_linear_4.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(True)

plt.show()

# %%
'''ytest=eed_data['y_test']
x_test = np.moveaxis(eed_data['x_test'], 1, 2)
x_test = scaler.transform(x_test.reshape(-1, x_test.shape[-1])).reshape(x_test.shape)
x_test = np.squeeze(x_test)
x_test.shape'''
# Out:
# "ytest=eed_data['y_test']\nx_test = np.moveaxis(eed_data['x_test'], 1, 2)\nx_test = scaler.transform(x_test.reshape(-1, x_test.shape[-1])).reshape(x_test.shape)\nx_test = np.squeeze(x_test)\nx_test.shape"

# %%
model.load_weights("D:/lab_work_25/AUG/audio visual eeg/eeg_classifier/Rest Vs Yes/model_weights/audio_visual_yes_no_part2.h5")

# %%
model.build(input_shape=(None, 128, 14))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               multiple                  600
#
#  dense_1 (Dense)             multiple                  600
#
#  dense_2 (Dense)             multiple                  1640
#
#  dense_3 (Dense)             multiple                  1640
#
#  kuramoto_local (KuramotoLoc  multiple                 1640
#  al)
#
#  dense_4 (Dense)             multiple                  820
#
#  dropout (Dropout)           multiple                  0
#
#  dense_5 (Dense)             multiple                  820
#
#  dropout_1 (Dropout)         multiple                  0
#
#  dense_6 (Dense)             multiple                  82
#
# =================================================================
# Total params: 7,842
# Trainable params: 6,242
# Non-trainable params: 1,600
# _________________________________________________________________

# %%
'''import numpy as np

# Example batch size and ytrain shape for demonstration
batch_size = 5642
ytest = ytest   # Generate a random ytrain for demonstration

# Initialize an empty list to store the results for all samples
all_samples_test = []

# Iterate over each sample in the batch
for sample in ytest:
    ans = []
    for i in sample:
        if i == 1:
            s = np.linspace(0, 0.25, 32)
            ans.append(s)
        else:
            s = np.zeros(32)
            ans.append(s)
    
    # Convert the list to a NumPy array and then transpose it to get (32, 10)
    ans_array = np.array(ans).T
    all_samples_test.append(ans_array)

# Convert the list of all_samples to a NumPy array
all_samples_test_array = np.array(all_samples_test)  # This should have shape (45083, 32, 10)

# Print the shape to verify
print("Shape of the final array:", all_samples_test_array.shape)

# Optionally, print the first sample to verify its content
print("First sample:\n", all_samples_test_array[0])'''
# Out:
# 'import numpy as np\n\n# Example batch size and ytrain shape for demonstration\nbatch_size = 5642\nytest = ytest   # Generate a random ytrain for demonstration\n\n# Initialize an empty list to store the results for all samples\nall_samples_test = []\n\n# Iterate over each sample in the batch\nfor sample in ytest:\n    ans = []\n    for i in sample:\n        if i == 1:\n            s = np.linspace(0, 0.25, 32)\n            ans.append(s)\n        else:\n            s = np.zeros(32)\n            ans.append(s)\n    \n    # Convert the list to a NumPy array and then transpose it to get (32, 10)\n    ans_array = np.array(ans).T\n    all_samples_test.append(ans_array)\n\n# Convert the list of all_samples to a NumPy array\nall_samples_test_array = np.array(all_samples_test)  # This should have shape (45083, 32, 10)\n\n# Print the shape to verify\nprint("Shape of the final array:", all_samples_test_array.shape)\n\n# Optionally, print the first sample to verify its content\nprint("First sample:\n", all_samples_test_array[0])'

# %%
X_test.shape
# Out:
# (176, 128, 14)

# %%
out_test = model.predict(X_test,batch_size=1)
# Out:
# 176/176 [==============================] - 9s 38ms/step

# %%
import numpy as np

def calculate_accuracy(out_test, all_samples_test_array):
    # Initialize the counter
    c_test = 0
    # Number of samples
    num_samples = out_test.shape[0]

    # Iterate over each sample
    for ii in range(num_samples):
        # Find the index of the maximum value in the current row of out_test
        a_test=sum(out_test[ii,:])
        indices_test = np.argmax(a_test)

        # Find the index of the maximum value in the current row of all_samples_test_array
        b_test=sum(all_samples_test_array[ii,:])
        indices1_test = np.argmax(b_test)

        # Check if the indices match
        if indices_test == indices1_test:
            c_test += 1

    # Calculate the accuracy
    accuracy = c_test / num_samples
    return accuracy

# Example usage
out_test1 = out_test  # Example data, replace with actual data
all_samples_test_array1 = y_test  # Example data, replace with actual data

accuracy = calculate_accuracy(out_test1, all_samples_test_array1)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9772727272727273

# %%
X_test
# Out:
# array([[[ 7.92804180e-02,  1.19785484e-01,  3.25551108e-02, ...,
#           7.02243262e-02,  8.02167839e-02,  1.07324086e-01],
#         [-4.62669260e-01, -4.30121656e-01, -2.82501139e-01, ...,
#          -9.00813082e-02, -2.60604577e-02, -1.89083526e-01],
#         [-9.00181809e-01, -8.96233996e-01, -5.26663236e-01, ...,
#          -2.20962811e-01, -1.29063816e-01, -4.25760862e-01],
#         ...,
#         [-5.06767905e-02,  1.69200940e-01, -6.38154829e-01, ...,
#          -1.15848485e-01,  2.23102726e-01, -1.51626363e-01],
#         [-1.17601962e-01, -1.56362613e-01, -5.48357035e-01, ...,
#          -3.75685522e-02,  1.40698236e-01, -1.05586771e-01],
#         [-1.39688870e-01, -3.92550915e-01, -3.11338000e-01, ...,
#           4.01777247e-02,  3.14509178e-02, -2.28929763e-02]],
#
#        [[ 4.66286911e-02, -5.93616101e-04,  7.80301847e-02, ...,
#           5.26618905e-02, -3.13331234e-02,  3.75509308e-02],
#         [ 9.25273473e-01,  4.18652686e-01,  1.44120745e+00, ...,
#           1.11034488e+00,  3.15105039e-01,  5.00566315e-01],
#         [ 1.56740045e+00,  7.34343347e-01,  2.46173903e+00, ...,
#           1.89814559e+00,  5.90218464e-01,  8.53864167e-01],
#         ...,
#         [ 3.47540174e-01,  2.13131757e-01,  1.05654240e+00, ...,
#           3.28127782e-01,  5.08367390e-01,  7.85967219e-01],
#         [ 3.82463087e-01,  2.53496847e-01,  8.27702122e-01, ...,
#           2.81095659e-01,  5.03502192e-01,  6.77113234e-01],
#         [ 2.79986602e-01,  1.86883442e-01,  3.64946501e-01, ...,
#           1.42996328e-01,  3.55500091e-01,  3.77407617e-01]],
#
#        [[-4.90418537e-02, -1.26268132e-01, -4.81401430e-02, ...,
#          -8.46239522e-02, -7.21104599e-02, -7.70760785e-02],
#         [ 2.35998107e-01,  1.15461530e-01,  1.18906657e-01, ...,
#          -1.94202546e-01, -5.25452675e-02, -5.54265380e-02],
#         [ 4.57515251e-01,  3.18989647e-01,  2.58552642e-01, ...,
#          -2.35239217e-01, -1.23082897e-03,  4.29987003e-03],
#         ...,
#         [-6.29680276e-01, -1.07013071e+00, -1.06024115e+00, ...,
#          -5.06598768e-01, -7.13508334e-01, -6.72192617e-01],
#         [-3.25039830e-01, -5.28310682e-01, -5.88638503e-01, ...,
#          -2.63185879e-01, -4.36983756e-01, -3.28428869e-01],
#         [ 5.08061330e-02,  1.02160620e-01,  7.77798817e-03, ...,
#           3.91501629e-02, -6.89631351e-02,  8.11067214e-02]],
#
#        ...,
#
#        [[-4.91110742e-02, -2.41279622e-02, -2.43342102e-02, ...,
#           8.76940977e-03,  2.29737502e-02,  3.64534417e-02],
#         [ 3.76899908e-01,  2.07343725e-01, -1.69847705e-02, ...,
#           1.12661735e-01, -1.35203179e-01,  4.48794356e-02],
#         [ 7.38838194e-01,  4.22240328e-01, -1.24614803e-02, ...,
#           2.42702560e-01, -2.23893350e-01,  9.18839844e-02],
#         ...,
#         [ 1.02192658e+00,  1.12118020e+00,  3.37091925e-02, ...,
#           9.81476475e-01,  1.20121959e-01,  5.73292383e-01],
#         [ 6.74371437e-01,  7.43383981e-01,  1.73570309e-02, ...,
#           6.47462499e-01,  3.01139740e-02,  3.67733083e-01],
#         [ 1.86881920e-01,  2.01918813e-01, -1.48889440e-03, ...,
#           1.94307292e-01, -5.34016769e-02,  8.98064056e-02]],
#
#        [[-2.86656335e-02, -8.73041006e-02, -3.31425526e-02, ...,
#           4.05884268e-02,  1.56282405e-02,  1.68908286e-02],
#         [-5.23439409e-01, -5.56782028e-01, -3.08397334e-01, ...,
#           2.24192381e-01,  7.19616198e-03,  1.65758797e-01],
#         [-9.17524049e-01, -9.08545461e-01, -5.53258279e-01, ...,
#           3.22729787e-01, -4.90216086e-03,  2.50821334e-01],
#         ...,
#         [-1.32185133e+00, -9.60493034e-01, -8.69674906e-01, ...,
#          -8.81732623e-01, -1.04776482e+00, -1.19621737e+00],
#         [-8.94108385e-01, -5.38128231e-01, -6.14332027e-01, ...,
#          -6.27439770e-01, -5.78927090e-01, -7.99802450e-01],
#         [-2.89646813e-01, -4.35569497e-02, -2.38179114e-01, ...,
#          -2.41008475e-01, -1.19055525e-02, -2.39242939e-01]],
#
#        [[ 1.19108528e-01,  1.19664697e-01, -2.07910445e-03, ...,
#           1.49946933e-01,  1.00768744e-01,  1.43091580e-01],
#         [-5.83136357e-01, -3.96639828e-01, -3.02193864e-02, ...,
#          -1.72943785e-01, -2.93727910e-01, -3.65123985e-01],
#         [-1.11973007e+00, -8.09344241e-01, -4.74831333e-02, ...,
#          -4.35164490e-01, -5.94287109e-01, -7.64036552e-01],
#         ...,
#         [ 2.06496169e-02,  4.31456918e-02,  5.89607672e-02, ...,
#           1.23361399e+00,  9.11766287e-02,  3.47310815e-01],
#         [ 3.87445116e-02,  1.61033615e-01,  1.18665537e-02, ...,
#           8.57469454e-01,  3.88969408e-02,  2.33424843e-01],
#         [ 6.42430136e-02,  2.39461010e-01, -3.22348358e-02, ...,
#           3.02135570e-01,  4.80561921e-03,  8.87209056e-02]]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import tensorflow as tf

# ==============================
# Extract coupling matrix helper
# ==============================
def get_coupling_matrix(model, X_batch):
    """
    Runs a forward pass with X_batch and returns the learned coupling matrix K.
    """
    # Reset K if you want a fresh Hebbian update before each forward pass
    model.osc1.K.assign(tf.zeros_like(model.osc1.K))

    # Run forward pass (testing mode)
    _ = model(X_batch, training=False)

    # Extract final K (after Hebbian updates)
    return model.osc1.K.numpy()

# ==============================
# Example usage with test data
# ==============================
# Suppose you have test data separated into two classes
# X_class0, X_class1 with shapes (batch, time, features)

# Take a few samples from each class
K0 = get_coupling_matrix(model, X_cls0_inter)   # coupling for class 0
K1 = get_coupling_matrix(model, X_cls1_inter)   # coupling for class 1

# Compute difference
K_diff = K1 - K0

# ==============================
# Visualization
# ==============================
plt.figure(figsize=(15,5))
for i, (mat, title) in enumerate(zip([K0, K1, K_diff],
                                     ["Class 0 Coupling (K0)", 
                                      "Class 1 Coupling (K1)", 
                                      "Difference (K1 - K0)"])):
    plt.subplot(1,3,i+1)
    sns.heatmap(mat, cmap="coolwarm", center=0, square=True, cbar=True)
    plt.title(title)
plt.tight_layout()
plt.show()

# ==============================
# Optional quantitative metrics
# ==============================
fro_norm = np.linalg.norm(K_diff)
print("Frobenius norm of difference:", fro_norm)
# Out:
# Frobenius norm of difference: 0.23205656

# %%
# ==============================
# Identify strongest connections
# ==============================
def analyze_strongest_changes(K0, K1, top_k=10):
    K_diff = K1 - K0
    n = K_diff.shape[0]

    # Flatten (i,j) pairs and values
    connections = []
    for i in range(n):
        for j in range(n):
            if i != j:  # ignore self-coupling
                connections.append(((i, j), K_diff[i, j]))

    # Sort by absolute difference
    connections_sorted = sorted(connections, key=lambda x: abs(x[1]), reverse=True)

    # Print top changes
    print(f"\nTop {top_k} strongest coupling differences:")
    for (i, j), val in connections_sorted[:top_k]:
        if val > 0:
            print(f"Oscillator {i} → {j} stronger in Class 1 by {val:.4f}")
        else:
            print(f"Oscillator {i} → {j} stronger in Class 0 by {abs(val):.4f}")

    return connections_sorted[:top_k], K_diff

# Run analysis
top_changes, K_diff = analyze_strongest_changes(K0, K1, top_k=10)
# Out:
# Top 10 strongest coupling differences:
# Oscillator 14 → 15 stronger in Class 1 by 0.0506
# Oscillator 15 → 14 stronger in Class 1 by 0.0506
# Oscillator 34 → 35 stronger in Class 0 by 0.0415
# Oscillator 35 → 34 stronger in Class 0 by 0.0415
# Oscillator 27 → 29 stronger in Class 1 by 0.0400
# Oscillator 29 → 27 stronger in Class 1 by 0.0400
# Oscillator 20 → 21 stronger in Class 0 by 0.0366
# Oscillator 21 → 20 stronger in Class 0 by 0.0366
# Oscillator 28 → 29 stronger in Class 1 by 0.0359
# Oscillator 29 → 28 stronger in Class 1 by 0.0359

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# ======================================================
# Hebbian update
# ======================================================
def hebbian_update(K, x, lr=0.01):
    """
    One step Hebbian update of coupling matrix.
    """
    x = x.reshape(-1, 1)   # column vector
    delta_K = lr * (x @ x.T)
    return K + delta_K

# ======================================================
# Compute coupling matrices over time for one trial
# ======================================================
def get_coupling_matrices_over_time(model, X_trial, lr=0.01):
    """
    Given a trial, evolve Hebbian coupling matrix K(t) over time.
    """
    states = model(X_trial, training=False).numpy()  # (1, T, N)
    states = states[0]  # (T, N)

    N = states.shape[1]
    K = np.zeros((N, N))
    Ks = []

    for t in range(states.shape[0]):
        x_t = states[t]
        K = hebbian_update(K, x_t, lr=lr)
        Ks.append(K.copy())

    return np.array(Ks)  # (T, N, N)

# ======================================================
# Average coupling snapshots across trials
# ======================================================
def get_avg_coupling_snapshots(model, X_trials, time_steps, lr=0.01):
    snapshots = {t: [] for t in time_steps}

    for trial in X_trials:
        Ks = get_coupling_matrices_over_time(model, trial[np.newaxis, ...], lr=lr)
        T = len(Ks)
        for t in time_steps:
            t_idx = t if t >= 0 else T + t
            if 0 <= t_idx < T:
                snapshots[t].append(Ks[t_idx])

    # Average across trials
    for t in snapshots:
        if len(snapshots[t]) > 0:
            snapshots[t] = np.mean(snapshots[t], axis=0)
        else:
            snapshots[t] = None
    return snapshots

# ======================================================
# Plot snapshots in a grid
# ======================================================
def plot_snapshots_grid(snapshots, title_prefix=""):
    n = len([k for k in snapshots if snapshots[k] is not None])
    cols = min(5, n)   # up to 5 columns per row
    rows = int(np.ceil(n / cols))

    fig, axes = plt.subplots(rows, cols, figsize=(4*cols, 4*rows))
    if rows == 1 and cols == 1:
        axes = np.array([[axes]])
    elif rows == 1:
        axes = np.array([axes])

    for ax, (t, K) in zip(axes.flatten(), snapshots.items()):
        if K is None:
            ax.axis("off")
            continue
        im = ax.imshow(K, cmap="bwr", aspect="auto")
        ax.set_title(f"t={t}")
        ax.set_xlabel("Oscillator index")
        ax.set_ylabel("Oscillator index")
    fig.suptitle(f"{title_prefix} Coupling Snapshots", fontsize=16)
    fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.6)
    plt.tight_layout()
    plt.show()

# ======================================================
# Helper: create evenly spaced snapshots
# ======================================================
def make_time_steps(total_points=128, n_snapshots=8, include_last=True):
    """
    Split total_points into n_snapshots evenly spaced time steps.
    Optionally include the very last time step (-1).
    """
    step = total_points // n_snapshots
    times = list(range(0, total_points, step))
    if include_last and times[-1] != total_points - 1:
        times.append(-1)
    return times

# ======================================================
# Example usage
# ======================================================

# Example: get 8 evenly spaced snapshots + last step
time_steps = make_time_steps(total_points=128, n_snapshots=8, include_last=True)

# Average snapshots across first 20 trials of each class
snapshots_class0 = get_avg_coupling_snapshots(model, X_cls0_inter[:20], time_steps, lr=0.01)
snapshots_class1 = get_avg_coupling_snapshots(model, X_cls1_inter[:20], time_steps, lr=0.01)

# Plot both classes
plot_snapshots_grid(snapshots_class0, title_prefix="Class 0")
plot_snapshots_grid(snapshots_class1, title_prefix="Class 1")
# Out:
# C:\Users\SAYANG~1\AppData\Local\Temp/ipykernel_17808/2088178953.py:83: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import tensorflow as tf

# ==============================
# Extract coupling matrix helper
# ==============================
def get_coupling_matrix(model, X_batch):
    """
    Runs a forward pass with X_batch and returns the learned coupling matrix K.
    """
    # Reset K before forward pass (for clean Hebbian update)
    model.osc1.K.assign(tf.zeros_like(model.osc1.K))

    # Run forward pass
    _ = model(X_batch, training=False)

    # Extract final K
    return model.osc1.K.numpy()

# ==============================
# Example usage with test data
# ==============================
# Suppose you already have X_cls0_inter and X_cls1_inter
K0 = get_coupling_matrix(model, X_cls0_inter)   # class 0 coupling
K1 = get_coupling_matrix(model, X_cls1_inter)   # class 1 coupling

# Difference
K_diff = K1 - K0

# ==============================
# Visualization
# ==============================
oscillators = range(1, K0.shape[0] + 1)  # oscillator indices (1–40)

plt.figure(figsize=(18, 6))
for i, (mat, title) in enumerate(zip(
        [K0, K1, K_diff],
        ["Class 0 Coupling (K0)", 
         "Class 1 Coupling (K1)", 
         "Difference (K1 - K0)"])):
    plt.subplot(1, 3, i+1)
    sns.heatmap(mat, cmap="coolwarm", center=0, square=True,
                xticklabels=oscillators, yticklabels=oscillators, cbar=True)
    plt.title(title)
    plt.xlabel("Oscillator j")
    plt.ylabel("Oscillator i")

plt.tight_layout()
plt.show()

# ==============================
# Quantitative analysis
# ==============================
fro_norm = np.linalg.norm(K_diff)
print("Frobenius norm of difference:", fro_norm)

# Flatten differences (excluding diagonal self-connections)
diff_abs = np.abs(K_diff)
np.fill_diagonal(diff_abs, 0)

# Find strongest differing connections
top_n = 10
indices = np.unravel_index(np.argsort(diff_abs.ravel())[::-1], K_diff.shape)
top_pairs = list(zip(indices[0][:top_n], indices[1][:top_n]))
top_values = [K_diff[i, j] for i, j in top_pairs]

print(f"\nTop {top_n} oscillator connections differing between Class 0 and Class 1:")
for (i, j), val in zip(top_pairs, top_values):
    stronger_class = "Class 1" if val > 0 else "Class 0"
    print(f"Oscillator {i+1} ↔ {j+1}: ΔK = {val:.4f} (stronger in {stronger_class})")
# Out:
# Frobenius norm of difference: 0.23205656
#
# Top 10 oscillator connections differing between Class 0 and Class 1:
# Oscillator 15 ↔ 16: ΔK = 0.0506 (stronger in Class 1)
# Oscillator 16 ↔ 15: ΔK = 0.0506 (stronger in Class 1)
# Oscillator 36 ↔ 35: ΔK = -0.0415 (stronger in Class 0)
# Oscillator 35 ↔ 36: ΔK = -0.0415 (stronger in Class 0)
# Oscillator 30 ↔ 28: ΔK = 0.0400 (stronger in Class 1)
# Oscillator 28 ↔ 30: ΔK = 0.0400 (stronger in Class 1)
# Oscillator 22 ↔ 21: ΔK = -0.0366 (stronger in Class 0)
# Oscillator 21 ↔ 22: ΔK = -0.0366 (stronger in Class 0)
# Oscillator 30 ↔ 29: ΔK = 0.0359 (stronger in Class 1)
# Oscillator 29 ↔ 30: ΔK = 0.0359 (stronger in Class 1)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# =====================================
# Utilities: adjacency (local coupling)
# =====================================

def build_ring_adjacency(units: int, neighbors: int = 2, periodic: bool = True) -> tf.Tensor:
    adj = np.zeros((units, units), dtype=np.float32)
    for i in range(units):
        for d in range(1, neighbors + 1):
            if periodic:
                j1 = (i - d) % units
                j2 = (i + d) % units
                adj[i, j1] = 1.0
                adj[i, j2] = 1.0
            else:
                j1 = i - d
                j2 = i + d
                if 0 <= j1 < units:
                    adj[i, j1] = 1.0
                if 0 <= j2 < units:
                    adj[i, j2] = 1.0
    np.fill_diagonal(adj, 0.0)
    return tf.convert_to_tensor(adj, dtype=tf.float32)

def zero_diag(x: tf.Tensor) -> tf.Tensor:
    n = tf.shape(x)[0]
    return x * (1.0 - tf.eye(n, dtype=x.dtype))


# =====================================
# Kuramoto loop: local coupling + Hebbian
# =====================================

@tf.function
def kuramoto_loop_local_hebb(
    X_r: tf.Tensor,
    X_i: tf.Tensor,
    omegas: tf.Tensor,
    num_steps: int,
    K: tf.Variable,
    adjacency: tf.Tensor,
    *,
    dt: float = 1.0/128.0,
    input_scaler: float = 2.0,
    eta: float = 0.01,
    decay: float = 0.001,
    k_clip: float = 1.0,
    wrap_phase: bool = True,
    normalize_rows: bool = False,
    symmetric_K: bool = True,
) -> tuple[tf.Tensor, tf.Variable]:

    batch = tf.shape(X_r)[0]
    units = tf.shape(X_r)[-1]

    phi_arr = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
    phis = tf.zeros((batch, units), dtype=tf.float32)  # initial phase = 0

    if normalize_rows:
        deg = tf.reduce_sum(adjacency, axis=1, keepdims=True)
        deg = tf.maximum(deg, 1.0)

    two_pi = tf.constant(2.0 * np.pi, dtype=tf.float32)
    pi = tf.constant(np.pi, dtype=tf.float32)

    for t in tf.range(num_steps):
        # External input
        input_r = input_scaler * X_r[:, t, :] * tf.math.cos(phis)
        input_i = input_scaler * X_i[:, t, :] * tf.math.sin(phis)

        # Coupling
        delta = tf.expand_dims(phis, 1) - tf.expand_dims(phis, 2)  # (batch, i, j)
        sin_term = -tf.math.sin(delta)
        K_eff = adjacency * K
        if normalize_rows:
            K_eff = K_eff / deg
        coup = tf.einsum('ij,bij->bi', K_eff, sin_term)

        # Update
        dphi = (omegas + input_r - input_i + coup) * dt
        phis = phis + dphi

        if wrap_phase:
            phis = ((phis + pi) % two_pi) - pi

        # Hebbian update
        hebb = tf.reduce_mean(tf.math.cos(delta), axis=0)
        dK = eta * (adjacency * hebb) - decay * K
        K.assign_add(dK)

        if symmetric_K:
            K.assign(0.5 * (K + tf.transpose(K)))
        K.assign(zero_diag(K))
        if k_clip is not None:
            K.assign(tf.clip_by_value(K, -k_clip, k_clip))

        phi_arr = phi_arr.write(phi_arr.size(), phis)

    phis = tf.transpose(phi_arr.stack(), [1, 0, 2])  # (batch, time, units)
    return phis, K


# =====================================
# Kuramoto Layer with Hebbian K
# =====================================

class KuramotoLocal(tf.keras.layers.Layer):
    def __init__(self, units: int, num_steps: int, *, 
                 min_omega=7.1, max_omega=15.1, train_omegas=True,
                 neighbors=2, periodic=True, eta=0.001, decay=0.001,
                 k_clip=1.0, normalize_rows=False, symmetric_K=True,
                 dt=1.0/128.0, input_scaler=2.0, wrap_phase=True, name=None, **kwargs):
        super().__init__(name=name, **kwargs)
        self.units = units
        self.num_steps = num_steps
        self.min_omega = min_omega
        self.max_omega = max_omega
        self.train_omegas = train_omegas
        self.neighbors = neighbors
        self.periodic = periodic
        self.eta = eta
        self.decay = decay
        self.k_clip = k_clip
        self.normalize_rows = normalize_rows
        self.symmetric_K = symmetric_K
        self.dt = dt
        self.input_scaler = input_scaler
        self.wrap_phase = wrap_phase

        omega_init = tf.random.uniform((1, units), -1, 1)
        self.omegas = tf.Variable(omega_init, trainable=train_omegas, name="omegas")

        k_init = tf.random.uniform((units, units), -0.05, 0.05)
        self.K = tf.Variable(k_init, trainable=False, name="K")

        self.adjacency = build_ring_adjacency(units, neighbors, periodic)

    def call(self, X_r: tf.Tensor, X_i: tf.Tensor):
        omega_range = self.max_omega - self.min_omega
        omega_inp = tf.sigmoid(0.5 * self.omegas) * omega_range + self.min_omega

        phis, _ = kuramoto_loop_local_hebb(
            X_r, X_i, omega_inp, self.num_steps,
            self.K, self.adjacency,
            dt=self.dt, input_scaler=self.input_scaler,
            eta=self.eta, decay=self.decay, k_clip=self.k_clip,
            wrap_phase=self.wrap_phase, normalize_rows=self.normalize_rows,
            symmetric_K=self.symmetric_K,
        )

        z_real = tf.math.cos(phis)
        z_imag = tf.math.sin(phis)
        return z_real, z_imag, phis  # also return phases


# =====================================
# End-to-end model
# =====================================

class Model(tf.keras.Model):
    def __init__(self, units1, units2, units3, units4, **kwargs):
        super().__init__(**kwargs)
        self.d1_r = tf.keras.layers.Dense(units1, activation='relu')
        self.d1_i = tf.keras.layers.Dense(units1, activation='relu')

        self.proj_r = tf.keras.layers.Dense(units2, activation=None)
        self.proj_i = tf.keras.layers.Dense(units2, activation=None)

        self.osc1 = KuramotoLocal(units=units2, num_steps=128)

        self.d_r = tf.keras.layers.Dense(units3, activation='tanh')
        self.dropout_r = tf.keras.layers.Dropout(0.3)
        self.d_i = tf.keras.layers.Dense(units3, activation='tanh')
        self.dropout_i = tf.keras.layers.Dropout(0.3)

        self.dense = tf.keras.layers.Dense(units4, activation='linear')

    def call(self, X: tf.Tensor, training=False):
        td = tf.keras.layers.TimeDistributed
        out1_r = td(self.d1_r)(X)
        out1_i = td(self.d1_i)(X)

        X_r = td(self.proj_r)(out1_r)
        X_i = td(self.proj_i)(out1_i)

        z1_r, z1_i, phis = self.osc1(X_r, X_i)

        out2_r = td(self.d_r)(z1_r)
        out2_r = td(self.dropout_r)(out2_r, training=training)
        out2_i = td(self.d_i)(z1_i)
        out2_i = td(self.dropout_i)(out2_i, training=training)

        concat_inp = tf.concat([out2_r, out2_i], axis=-1)
        denseout = td(self.dense)(concat_inp)
        return denseout, phis


# =====================================
# Synchrony measures
# =====================================

def kuramoto_order_parameter(phis):
    z = np.exp(1j * phis)  # (batch, time, units)
    R_t = np.abs(np.mean(z, axis=-1))  # (batch, time)
    return R_t

def phase_locking_value(phis):
    batch, T, N = phis.shape
    plv = np.zeros((N, N))
    for i in range(N):
        for j in range(N):
            if i == j: continue
            phase_diff = phis[:, :, i] - phis[:, :, j]
            val = np.abs(np.mean(np.exp(1j * phase_diff)))
            plv[i, j] = val
    return plv


# =====================================
# Example usage
# =====================================
if __name__ == "__main__":
    # Dummy EEG/rest data (replace with real)
    batch, time_steps, features = 10, 128, 14
    X_cls0_inter = X_cls0_inter
    X_cls1_inter = X_cls1_inter

    model = Model(40,40,20,2)

    # Forward pass for two classes
    _, phis0 = model(X_cls0_inter)
    _, phis1 = model(X_cls1_inter)

    phis0 = phis0.numpy()
    phis1 = phis1.numpy()

    # Global synchrony R(t)
    R0 = kuramoto_order_parameter(phis0)
    R1 = kuramoto_order_parameter(phis1)

    plt.plot(np.mean(R0, axis=0), label="Class 0 (EEG)")
    plt.plot(np.mean(R1, axis=0), label="Class 1 (Rest)")
    plt.xlabel("Time")
    plt.ylabel("Global synchrony R(t)")
    plt.legend()
    plt.show()

    # Pairwise PLV
    plv0 = phase_locking_value(phis0)
    plv1 = phase_locking_value(phis1)

    fig, ax = plt.subplots(1, 2, figsize=(10,4))
    im0 = ax[0].imshow(plv0, cmap="hot", vmin=0, vmax=1)
    ax[0].set_title("Class 0 PLV")
    im1 = ax[1].imshow(plv1, cmap="hot", vmin=0, vmax=1)
    ax[1].set_title("Class 1 PLV")
    plt.colorbar(im0, ax=ax.ravel().tolist(), shrink=0.6)
    plt.show()

# %%
delta_PLV = plv0 - plv1

# 2. Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(delta_PLV, cmap="bwr", center=0, square=True,
            xticklabels=np.arange(40), yticklabels=np.arange(40))
plt.title("ΔPLV (Class1 - Class0)", fontsize=14)
plt.xlabel("Oscillator Index")
plt.ylabel("Oscillator Index")
plt.tight_layout()
plt.show()

# 3. Find top oscillator pairs with largest absolute difference
num_top = 10  # how many pairs to show
indices = np.triu_indices_from(delta_PLV, k=1)  # upper triangle only (i<j)
diff_values = delta_PLV[indices]
sorted_idx = np.argsort(np.abs(diff_values))[::-1]  # sort by magnitude

print(f"\nTop {num_top} oscillator pairs with largest |ΔPLV|:")
for k in range(num_top):
    i = indices[0][sorted_idx[k]]
    j = indices[1][sorted_idx[k]]
    print(f"Pair ({i}, {j}): ΔPLV = {diff_values[sorted_idx[k]]:.4f}")
# Out:
# Top 10 oscillator pairs with largest |ΔPLV|:
# Pair (15, 33): ΔPLV = -0.0632
# Pair (0, 23): ΔPLV = 0.0553
# Pair (14, 33): ΔPLV = -0.0536
# Pair (18, 23): ΔPLV = 0.0535
# Pair (15, 38): ΔPLV = -0.0534
# Pair (22, 23): ΔPLV = 0.0511
# Pair (23, 26): ΔPLV = 0.0492
# Pair (0, 12): ΔPLV = 0.0476
# Pair (15, 18): ΔPLV = 0.0475
# Pair (6, 16): ΔPLV = -0.0470

# %%
def phase_locking_value(phis: np.ndarray) -> np.ndarray:
    """
    Compute PLV across oscillator pairs.
    phis: (batch, time, units)
    """
    batch, T, N = phis.shape
    # Expand for pairwise differences: (batch, time, N, N)
    delta = np.expand_dims(phis, -1) - np.expand_dims(phis, -2)
    exp_diff = np.exp(1j * delta)
    plv = np.abs(np.mean(exp_diff, axis=(0, 1)))  # (N, N)
    np.fill_diagonal(plv, 0.0)  # no self-PLV
    return plv

# %%
vmin, vmax = 0, 1
fig, ax = plt.subplots(1, 2, figsize=(10,4))
im0 = ax[0].imshow(plv0, cmap="hot", vmin=vmin, vmax=vmax)
ax[0].set_title("Class 0 PLV")
im1 = ax[1].imshow(plv1, cmap="hot", vmin=vmin, vmax=vmax)
ax[1].set_title("Class 1 PLV")
fig.colorbar(im0, ax=ax.ravel().tolist(), shrink=0.6, label="PLV")
plt.show()
